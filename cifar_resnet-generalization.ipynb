# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.parallel
import torch.nn.functional as F
# import torch.backends.cudnn as cudnn
from torch.autograd import Variable
import torch.optim
import torch.utils.data
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import numpy as np
from adastab import AdaStab
from OurAdam import Adam
# %matplotlib inline
import matplotlib.pyplot as plt
import scipy.io as sio

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion*planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2,2,2,2])

# %%
batch_size = 128
learning_rate = 1e-4
epochs = 10

# %%
transform_train = transforms.Compose([
    # transforms.RandomCrop(32, padding=4),
    # transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, 
                                       transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def cifartest():
        correct = 0
        total = torch.FloatTensor([0])
#     with torch.no_grad():
        test_loss = 0
        
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = Variable(inputs, volatile=True),Variable(targets, volatile=True)
            inputs, targets = inputs.cuda(), targets.cuda()
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            test_loss += loss
            
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += (predicted==targets).sum()
            
        print('test loss:{}'.format(test_loss/(batch_idx+1)))
        
        
#         print(total)
#         print(correct)
#         total = Variable(total, requires_grad=False)
#         total = total.cuda()
        correct = correct.data[0]
#         correct = torch.FloatTensor(correct)
#         correct = Varaible(correct, requires_grad=False)
#         correct = correct.cuda()
#         correct = torch.Tensor(correct)
        acc = correct/total
        print('Accuracy of the network on the 10000 test images: %f' % (
         acc))
        
        return test_loss/(batch_idx+1), acc

# %%
def cifartrain():
    for epoch in range(max_epoch):  # loop over the dataset multiple times

        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
        # get the inputs
            inputs, labels = data
            inputs = Variable(inputs)
            labels = Variable(labels)
            inputs = inputs.cuda()
            labels = labels.cuda()

        # zero the parameter gradients
            optimizer.zero_grad()

        # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss
        
        print('epoch{}, loss{}'.format(epoch, running_loss/(i+1)))
        LOSS[0, epoch] = running_loss/(i+1)
        # Test every epoch
        Test_LOSS[0, epoch], TEST_Acc[0, epoch] = cifartest()
    
    print('Finished Training')
    return LOSS, Test_LOSS, TEST_Acc

# %%
max_epoch=10
# No test

# %% [markdown]
# ### AMSGrad

# %%
# learning_rate = 7e-5
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, amsgrad=True)
# LOSS, Test_LOSS= cifartrain()

# %%
# learning_rate = 6e-5
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# TEST_Acc = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.1, amsgrad=True)
# LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.4267
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1588
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015400
# epoch1, lossVariable containing:
#  0.9894
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9523
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002600
# epoch2, lossVariable containing:
#  0.7920
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8006
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012700
# epoch3, lossVariable containing:
#  0.6621
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7656
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023700
# epoch4, lossVariable containing:
#  0.5738
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7168
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016500
# epoch5, lossVariable containing:
#  0.4997
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6745
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004300
# epoch6, lossVariable containing:
#  0.4487
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6666
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007700
# epoch7, lossVariable containing:
#  0.3951
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6753
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007200
# epoch8, lossVariable containing:
#  0.3539
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6774
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008700
# epoch9, lossVariable containing:
#  0.3190
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6769
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009400
# Finished Training

# %%
# learning_rate = 6e-5
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# TEST_Acc = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.2, amsgrad=True)
# LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.4708
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1770
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018900
# epoch1, lossVariable containing:
#  1.0185
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9832
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022200
# epoch2, lossVariable containing:
#  0.8357
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8277
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005800
# epoch3, lossVariable containing:
#  0.7187
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7435
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011400
# epoch4, lossVariable containing:
#  0.6420
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6931
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009200
# epoch5, lossVariable containing:
#  0.5824
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6888
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005800
# epoch6, lossVariable containing:
#  0.5337
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6498
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022200
# epoch7, lossVariable containing:
#  0.5024
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6437
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000100
# epoch8, lossVariable containing:
#  0.4739
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6250
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007200
# epoch9, lossVariable containing:
#  0.4461
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6314
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005400
# Finished Training

# %%
learning_rate = 6e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=True)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.5183
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2324
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021400
# epoch1, lossVariable containing:
#  1.0536
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9876
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022000
# epoch2, lossVariable containing:
#  0.8667
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8873
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014200
# epoch3, lossVariable containing:
#  0.7541
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7527
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011700
# epoch4, lossVariable containing:
#  0.6842
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7317
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023100
# epoch5, lossVariable containing:
#  0.6318
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6915
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012400
# epoch6, lossVariable containing:
#  0.5871
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6771
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017000
# epoch7, lossVariable containing:
#  0.5539
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6814
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012900
# epoch8, lossVariable containing:
#  0.5295
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6340
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002800
# epoch9, lossVariable containing:
#  0.5114
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6184
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010700
# Finished Training

# %%
# learning_rate = 6e-5
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# TEST_Acc = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.5, amsgrad=True)
# LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.5818
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2862
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009000
# epoch1, lossVariable containing:
#  1.1629
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.0834
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022500
# epoch2, lossVariable containing:
#  0.9596
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9240
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007900
# epoch3, lossVariable containing:
#  0.8386
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8606
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003300
# epoch4, lossVariable containing:
#  0.7649
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7745
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014100
# epoch5, lossVariable containing:
#  0.7059
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7626
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021300
# epoch6, lossVariable containing:
#  0.6678
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7223
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007600
# epoch7, lossVariable containing:
#  0.6343
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7077
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012800
# epoch8, lossVariable containing:
#  0.6133
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6846
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000400
# epoch9, lossVariable containing:
#  0.5895
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7034
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015500
# Finished Training

# %%
# learning_rate = 1e-4
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# TEST_Acc = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=True)
# LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.4528
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1747
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015200
# epoch1, lossVariable containing:
#  1.0529
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9826
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002500
# epoch2, lossVariable containing:
#  0.8919
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8673
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000600
# epoch3, lossVariable containing:
#  0.7935
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8222
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010400
# epoch4, lossVariable containing:
#  0.7463
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7913
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009500
# epoch5, lossVariable containing:
#  0.7073
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7532
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024300
# epoch6, lossVariable containing:
#  0.6815
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7422
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024100
# epoch7, lossVariable containing:
#  0.6572
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6969
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016400
# epoch8, lossVariable containing:
#  0.6383
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7009
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015900
# epoch9, lossVariable containing:
#  0.6225
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6839
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023700
# Finished Training

# %%
# learning_rate = 5e-5
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, amsgrad=True)
# LOSS, Test_LOSS= cifartrain()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-7e8e79a329fc> in <module>()
#       6 Test_LOSS = np.zeros([1, max_epoch])
#       7 optimizer = Adam(net.parameters(), lr=learning_rate, amsgrad=True)
# ----> 8 LOSS, Test_LOSS= cifartrain()
#
# <ipython-input-28-337c8a4f0bfd> in cifartrain()
#       8             inputs = Variable(inputs)
#       9             labels = Variable(labels)
# ---> 10             inputs = inputs.cuda()
#      11             labels = labels.cuda()
#      12
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/autograd/variable.py in cuda(self, device, async)
#     296
#     297     def cuda(self, device=None, async=False):
# --> 298         return CudaTransfer.apply(self, device, async)
#     299
#     300     def cpu(self):
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, device, async)
#     199             return i.cuda(device, async=async)
#     200         else:
# --> 201             return i.cuda(async=async)
#     202
#     203     @staticmethod
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/_utils.py in _cuda(self, device, async)
#      67         else:
#      68             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 69             return new_type(self.size()).copy_(self, async)
#      70
#      71
#
# KeyboardInterrupt:

# %%
# learning_rate = 4e-5
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, amsgrad=True)
# LOSS, Test_LOSS= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.4387
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch1, lossVariable containing:
#  0.9976
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch2, lossVariable containing:
#  0.7389
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch3, lossVariable containing:
#  0.4958
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch4, lossVariable containing:
#  0.2694
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch5, lossVariable containing:
#  0.1239
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch6, lossVariable containing:
# 1.00000e-02 *
#   5.3022
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch7, lossVariable containing:
# 1.00000e-02 *
#   2.3029
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch8, lossVariable containing:
# 1.00000e-02 *
#   1.3496
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch9, lossVariable containing:
# 1.00000e-03 *
#   8.2493
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Finished Training

# %%
# learning_rate = 3e-5
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, amsgrad=True)
# LOSS, Test_LOSS= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.5133
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch1, lossVariable containing:
#  1.1000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch2, lossVariable containing:
#  0.8518
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch3, lossVariable containing:
#  0.6116
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch4, lossVariable containing:
#  0.3754
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch5, lossVariable containing:
#  0.1989
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch6, lossVariable containing:
# 1.00000e-02 *
#   9.3962
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch7, lossVariable containing:
# 1.00000e-02 *
#   4.7172
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch8, lossVariable containing:
# 1.00000e-02 *
#   2.6213
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch9, lossVariable containing:
# 1.00000e-02 *
#   1.6869
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Finished Training

# %% [markdown]
# Adam

# %%
learning_rate = 6e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=False)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.5102
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2209
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009200
# epoch1, lossVariable containing:
#  1.0599
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9607
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012800
# epoch2, lossVariable containing:
#  0.8640
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8654
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024800
# epoch3, lossVariable containing:
#  0.7568
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8255
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012600
# epoch4, lossVariable containing:
#  0.6856
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7023
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006100
# epoch5, lossVariable containing:
#  0.6389
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6906
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009100
# epoch6, lossVariable containing:
#  0.6026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6649
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020400
# epoch7, lossVariable containing:
#  0.5616
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6797
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013200
# epoch8, lossVariable containing:
#  0.5349
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6422
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004300
# epoch9, lossVariable containing:
#  0.5142
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6160
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012300
# Finished Training

# %%
learning_rate = 6e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.4, amsgrad=False)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.5454
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2125
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010200
# epoch1, lossVariable containing:
#  1.0935
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.0395
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006000
# epoch2, lossVariable containing:
#  0.9070
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9144
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010500
# epoch3, lossVariable containing:
#  0.7877
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8214
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014700
# epoch4, lossVariable containing:
#  0.7214
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7814
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008800
# epoch5, lossVariable containing:
#  0.6708
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7047
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009400
# epoch6, lossVariable containing:
#  0.6320
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7159
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003100
# epoch7, lossVariable containing:
#  0.5975
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7013
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012700
# epoch8, lossVariable containing:
#  0.5753
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6757
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019600
# epoch9, lossVariable containing:
#  0.5490
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6638
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006300
# Finished Training

# %%
learning_rate = 6e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.2, amsgrad=False)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.4784
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1815
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014700
# epoch1, lossVariable containing:
#  1.0455
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9942
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013200
# epoch2, lossVariable containing:
#  0.8522
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8351
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002500
# epoch3, lossVariable containing:
#  0.7291
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7927
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020800
# epoch4, lossVariable containing:
#  0.6514
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7403
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013400
# epoch5, lossVariable containing:
#  0.5909
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7181
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021600
# epoch6, lossVariable containing:
#  0.5479
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6432
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023600
# epoch7, lossVariable containing:
#  0.5078
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6540
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020900
# epoch8, lossVariable containing:
#  0.4729
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6272
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001400
# epoch9, lossVariable containing:
#  0.4436
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6222
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010000
# Finished Training

# %%
max_epoch = 50

# %%
# learning_rate = 6e-5
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# TEST_Acc = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.4, amsgrad=False)
# LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.5556
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2139
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013400
# epoch1, lossVariable containing:
#  1.0915
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.0190
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017400
# epoch2, lossVariable containing:
#  0.9137
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8617
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001200
# epoch3, lossVariable containing:
#  0.7977
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001800
# epoch4, lossVariable containing:
#  0.7221
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7972
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022300
# epoch5, lossVariable containing:
#  0.6674
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7377
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000200
# epoch6, lossVariable containing:
#  0.6246
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6777
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022000
# epoch7, lossVariable containing:
#  0.5967
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7079
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009600
# epoch8, lossVariable containing:
#  0.5730
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6554
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006300
# epoch9, lossVariable containing:
#  0.5547
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6321
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015900
# epoch10, lossVariable containing:
#  0.5297
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6658
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007600
# epoch11, lossVariable containing:
#  0.5247
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6308
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021800
# epoch12, lossVariable containing:
#  0.5099
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6218
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000900
# epoch13, lossVariable containing:
#  0.4979
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6209
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025400
# epoch14, lossVariable containing:
#  0.4960
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6331
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023800
# epoch15, lossVariable containing:
#  0.4873
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6290
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001800
# epoch16, lossVariable containing:
#  0.4883
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6537
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020100
# epoch17, lossVariable containing:
#  0.4899
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6404
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004500
# epoch18, lossVariable containing:
#  0.4905
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6437
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006500
# epoch19, lossVariable containing:
#  0.4944
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6653
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002300
# epoch20, lossVariable containing:
#  0.5022
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6592
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007900
# epoch21, lossVariable containing:
#  0.5092
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6772
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008700
# epoch22, lossVariable containing:
#  0.5218
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6871
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008500
# epoch23, lossVariable containing:
#  0.5327
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7042
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010300
# epoch24, lossVariable containing:
#  0.5512
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7292
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007800
# epoch25, lossVariable containing:
#  0.5658
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7420
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013300
# epoch26, lossVariable containing:
#  0.5885
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7654
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013100
# epoch27, lossVariable containing:
#  0.6144
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7933
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012800
# epoch28, lossVariable containing:
#  0.6490
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8279
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006200
# epoch29, lossVariable containing:
#  0.6871
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8519
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015000
# epoch30, lossVariable containing:
#  0.7247
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9020
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-e65467ed1a71> in <module>()
#       7 TEST_Acc = np.zeros([1, max_epoch])
#       8 optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.4, amsgrad=False)
# ----> 9 LOSS, Test_LOSS, Test_Acc= cifartrain()
#
# <ipython-input-20-337c8a4f0bfd> in cifartrain()
#       8             inputs = Variable(inputs)
#       9             labels = Variable(labels)
# ---> 10             inputs = inputs.cuda()
#      11             labels = labels.cuda()
#      12
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/autograd/variable.py in cuda(self, device, async)
#     296
#     297     def cuda(self, device=None, async=False):
# --> 298         return CudaTransfer.apply(self, device, async)
#     299
#     300     def cpu(self):
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, device, async)
#     199             return i.cuda(device, async=async)
#     200         else:
# --> 201             return i.cuda(async=async)
#     202
#     203     @staticmethod
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/_utils.py in _cuda(self, device, async)
#      67         else:
#      68             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 69             return new_type(self.size()).copy_(self, async)
#      70
#      71
#
# KeyboardInterrupt:

# %%
# learning_rate = 6e-5
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# TEST_Acc = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.8, amsgrad=False)
# LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.6386
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3364
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025500
# epoch1, lossVariable containing:
#  1.1931
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1296
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003500
# epoch2, lossVariable containing:
#  1.0328
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9860
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011100
# epoch3, lossVariable containing:
#  0.9128
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8906
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001800
# epoch4, lossVariable containing:
#  0.8372
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8443
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020700
# epoch5, lossVariable containing:
#  0.7896
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7906
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012700
# epoch6, lossVariable containing:
#  0.7587
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7832
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022300
# epoch7, lossVariable containing:
#  0.7301
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7854
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021900
# epoch8, lossVariable containing:
#  0.7104
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7521
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011300
# epoch9, lossVariable containing:
#  0.6910
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7569
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013000
# epoch10, lossVariable containing:
#  0.6799
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7314
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000100
# epoch11, lossVariable containing:
#  0.6748
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7276
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005100
# epoch12, lossVariable containing:
#  0.6671
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7362
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003200
# epoch13, lossVariable containing:
#  0.6648
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7282
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010800
# epoch14, lossVariable containing:
#  0.6609
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7534
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008400
# epoch15, lossVariable containing:
#  0.6663
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7440
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012600
# epoch16, lossVariable containing:
#  0.6702
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7778
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003500
# epoch17, lossVariable containing:
#  0.6757
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8030
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002100
# epoch18, lossVariable containing:
#  0.6880
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7837
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014000
# epoch19, lossVariable containing:
#  0.6997
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8019
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014500
# epoch20, lossVariable containing:
#  0.7117
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8030
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018900
# epoch21, lossVariable containing:
#  0.7248
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8232
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019200
# epoch22, lossVariable containing:
#  0.7494
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8617
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017400
# epoch23, lossVariable containing:
#  0.7785
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8722
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000300
# epoch24, lossVariable containing:
#  0.8087
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8948
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024700
# epoch25, lossVariable containing:
#  0.8482
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9530
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017400
# epoch26, lossVariable containing:
#  0.8856
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9835
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023300
# epoch27, lossVariable containing:
#  0.9346
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.0415
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-9636201763b2> in <module>()
#       7 TEST_Acc = np.zeros([1, max_epoch])
#       8 optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.8, amsgrad=False)
# ----> 9 LOSS, Test_LOSS, Test_Acc= cifartrain()
#
# <ipython-input-20-337c8a4f0bfd> in cifartrain()
#       8             inputs = Variable(inputs)
#       9             labels = Variable(labels)
# ---> 10             inputs = inputs.cuda()
#      11             labels = labels.cuda()
#      12
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/autograd/variable.py in cuda(self, device, async)
#     296
#     297     def cuda(self, device=None, async=False):
# --> 298         return CudaTransfer.apply(self, device, async)
#     299
#     300     def cpu(self):
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, device, async)
#     199             return i.cuda(device, async=async)
#     200         else:
# --> 201             return i.cuda(async=async)
#     202
#     203     @staticmethod
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/_utils.py in _cuda(self, device, async)
#      67         else:
#      68             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 69             return new_type(self.size()).copy_(self, async)
#      70
#      71
#
# KeyboardInterrupt:

# %%
learning_rate = 6e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.6, amsgrad=False)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.6091
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3274
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021700
# epoch1, lossVariable containing:
#  1.1801
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.0966
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016400
# epoch2, lossVariable containing:
#  0.9945
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9390
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024500
# epoch3, lossVariable containing:
#  0.8654
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8358
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019300
# epoch4, lossVariable containing:
#  0.7924
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7953
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008400
# epoch5, lossVariable containing:
#  0.7328
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8055
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005900
# epoch6, lossVariable containing:
#  0.6962
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7345
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005900
# epoch7, lossVariable containing:
#  0.6654
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7160
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018700
# epoch8, lossVariable containing:
#  0.6401
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7207
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013700
# epoch9, lossVariable containing:
#  0.6234
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6994
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024600
# epoch10, lossVariable containing:
#  0.6103
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6823
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005000
# epoch11, lossVariable containing:
#  0.5991
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6725
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013800
# epoch12, lossVariable containing:
#  0.5905
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7049
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000000
# epoch13, lossVariable containing:
#  0.5764
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6888
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012000
# epoch14, lossVariable containing:
#  0.5775
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6734
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021900
# epoch15, lossVariable containing:
#  0.5795
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6872
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017200
# epoch16, lossVariable containing:
#  0.5779
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6762
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch17, lossVariable containing:
#  0.5787
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7141
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018200
# epoch18, lossVariable containing:
#  0.5881
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7131
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022700
# epoch19, lossVariable containing:
#  0.5905
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7354
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015000
# epoch20, lossVariable containing:
#  0.5998
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7201
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002100
# epoch21, lossVariable containing:
#  0.6165
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7386
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000600
# epoch22, lossVariable containing:
#  0.6268
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7502
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007400
# epoch23, lossVariable containing:
#  0.6445
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7874
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000000
# epoch24, lossVariable containing:
#  0.6649
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7884
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012200
# epoch25, lossVariable containing:
#  0.6935
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8180
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009600
# epoch26, lossVariable containing:
#  0.7229
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8735
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024200
# epoch27, lossVariable containing:
#  0.7626
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8901
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010100
# epoch28, lossVariable containing:
#  0.8042
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9358
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010200
# epoch29, lossVariable containing:
#  0.8515
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9918
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003200
# epoch30, lossVariable containing:
#  0.9125
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.0459
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004000
# epoch31, lossVariable containing:
#  0.9742
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1119
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023100
# epoch32, lossVariable containing:
#  1.0519
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1699
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007900
# epoch33, lossVariable containing:
#  1.1348
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2620
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024900
# epoch34, lossVariable containing:
#  1.2308
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3491
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006000
# epoch35, lossVariable containing:
#  1.3356
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4458
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006300
# epoch36, lossVariable containing:
#  1.4480
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5606
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022900
# epoch37, lossVariable containing:
#  1.5693
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6718
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005500
# epoch38, lossVariable containing:
#  1.7003
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7991
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022900
# epoch39, lossVariable containing:
#  1.8385
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9238
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009700
# epoch40, lossVariable containing:
#  1.9698
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.0407
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008900
# epoch41, lossVariable containing:
#  2.0860
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.1420
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009200
# epoch42, lossVariable containing:
#  2.1816
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2239
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006700
# epoch43, lossVariable containing:
#  2.2504
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2723
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022300
# epoch44, lossVariable containing:
#  2.2863
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2975
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018100
# epoch45, lossVariable containing:
#  2.3016
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch46, lossVariable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch47, lossVariable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch48, lossVariable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch49, lossVariable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# Finished Training

# %%
sio.savemat('adam_res_gen6.mat',{'loss':LOSS, 'test_loss':Test_LOSS, 'test_acc':Test_Acc})

# %%
learning_rate = 6e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.7, amsgrad=False)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.6283
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3517
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006900
# epoch1, lossVariable containing:
#  1.1905
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1275
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003400
# epoch2, lossVariable containing:
#  1.0000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9999
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002300
# epoch3, lossVariable containing:
#  0.8791
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8537
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014900
# epoch4, lossVariable containing:
#  0.8022
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7851
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012100
# epoch5, lossVariable containing:
#  0.7507
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7882
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015200
# epoch6, lossVariable containing:
#  0.7139
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7752
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021600
# epoch7, lossVariable containing:
#  0.6905
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7538
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002100
# epoch8, lossVariable containing:
#  0.6688
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7275
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017200
# epoch9, lossVariable containing:
#  0.6528
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7351
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017300
# epoch10, lossVariable containing:
#  0.6440
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7216
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019800
# epoch11, lossVariable containing:
#  0.6307
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7260
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022300
# epoch12, lossVariable containing:
#  0.6193
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7105
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008700
# epoch13, lossVariable containing:
#  0.6178
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7125
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009000
# epoch14, lossVariable containing:
#  0.6170
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6971
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018600
# epoch15, lossVariable containing:
#  0.6166
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7038
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016000
# epoch16, lossVariable containing:
#  0.6219
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7493
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003900
# epoch17, lossVariable containing:
#  0.6235
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6996
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001000
# epoch18, lossVariable containing:
#  0.6276
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7339
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020300
# epoch19, lossVariable containing:
#  0.6357
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7318
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003000
# epoch20, lossVariable containing:
#  0.6490
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7628
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021900
# epoch21, lossVariable containing:
#  0.6640
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7869
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022100
# epoch22, lossVariable containing:
#  0.6843
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8043
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020500
# epoch23, lossVariable containing:
#  0.7061
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8094
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004400
# epoch24, lossVariable containing:
#  0.7329
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8649
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015700
# epoch25, lossVariable containing:
#  0.7665
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8876
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025000
# epoch26, lossVariable containing:
#  0.8014
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9379
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019100
# epoch27, lossVariable containing:
#  0.8435
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.9541
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004000
# epoch28, lossVariable containing:
#  0.8962
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.0093
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025200
# epoch29, lossVariable containing:
#  0.9490
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.0691
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023600
# epoch30, lossVariable containing:
#  1.0183
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1285
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000500
# epoch31, lossVariable containing:
#  1.0861
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1968
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001500
# epoch32, lossVariable containing:
#  1.1699
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2744
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004000
# epoch33, lossVariable containing:
#  1.2623
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3769
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020400
# epoch34, lossVariable containing:
#  1.3629
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4674
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021400
# epoch35, lossVariable containing:
#  1.4750
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5833
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019400
# epoch36, lossVariable containing:
#  1.5961
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7015
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004700
# epoch37, lossVariable containing:
#  1.7226
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8126
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013400
# epoch38, lossVariable containing:
#  1.8526
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9335
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000300
# epoch39, lossVariable containing:
#  1.9776
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.0483
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024700
# epoch40, lossVariable containing:
#  2.0904
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.1447
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000200
# epoch41, lossVariable containing:
#  2.1820
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2217
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006600
# epoch42, lossVariable containing:
#  2.2475
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2717
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012900
# epoch43, lossVariable containing:
#  2.2833
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2938
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005400
# epoch44, lossVariable containing:
#  2.3002
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch45, lossVariable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch46, lossVariable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch47, lossVariable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch48, lossVariable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch49, lossVariable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# Finished Training

# %%
sio.savemat('adam_res_gen7.mat',{'loss':LOSS, 'test_loss':Test_LOSS, 'test_acc':Test_Acc})

# %%
# learning_rate = 6e-6
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# TEST_Acc = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.4, amsgrad=False)
# LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  2.1447
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9494
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013000
# epoch1, lossVariable containing:
#  1.7880
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6589
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch2, lossVariable containing:
#  1.5619
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4829
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006700
# epoch3, lossVariable containing:
#  1.3894
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3433
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005100
# epoch4, lossVariable containing:
#  1.2468
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2535
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016100
# epoch5, lossVariable containing:
#  1.1081
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1747
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025100
# epoch6, lossVariable containing:
#  0.9724
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1260
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020200
# epoch7, lossVariable containing:
#  0.8462
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1048
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004300
# epoch8, lossVariable containing:
#  0.7103
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.0964
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011000
# epoch9, lossVariable containing:
#  0.5795
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1172
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005600
# epoch10, lossVariable containing:
#  0.4568
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1620
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000900
# epoch11, lossVariable containing:
#  0.3624
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1710
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000300
# epoch12, lossVariable containing:
#  0.2856
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2082
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020300
# epoch13, lossVariable containing:
#  0.2416
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2347
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015700
# epoch14, lossVariable containing:
#  0.2106
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2280
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019700
# epoch15, lossVariable containing:
#  0.1940
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2433
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017100
# epoch16, lossVariable containing:
#  0.1808
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2439
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020600
# epoch17, lossVariable containing:
#  0.1741
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2466
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019700
# epoch18, lossVariable containing:
#  0.1634
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2608
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014200
# epoch19, lossVariable containing:
#  0.1660
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2859
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017100
# epoch20, lossVariable containing:
#  0.1621
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-886ad5f29d61> in <module>()
#       7 TEST_Acc = np.zeros([1, max_epoch])
#       8 optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.4, amsgrad=False)
# ----> 9 LOSS, Test_LOSS, Test_Acc= cifartrain()
#
# <ipython-input-20-337c8a4f0bfd> in cifartrain()
#      24         LOSS[0, epoch] = running_loss/(i+1)
#      25         # Test every epoch
# ---> 26         Test_LOSS[0, epoch], TEST_Acc[0, epoch] = cifartest()
#      27
#      28     print('Finished Training')
#
# <ipython-input-19-1c840884edf3> in cifartest()
#       8             inputs, targets = Variable(inputs, volatile=True),Variable(targets, volatile=True)
#       9             inputs, targets = inputs.cuda(), targets.cuda()
# ---> 10             outputs = net(inputs)
#      11             loss = criterion(outputs, targets)
#      12             test_loss += loss
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-2-ae89ddc90ab1> in forward(self, x)
#      77         out = self.layer1(out)
#      78         out = self.layer2(out)
# ---> 79         out = self.layer3(out)
#      80         out = self.layer4(out)
#      81         out = F.avg_pool2d(out, 4)
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-2-ae89ddc90ab1> in forward(self, x)
#      19         out = F.relu(self.bn1(self.conv1(x)))
#      20         out = self.bn2(self.conv2(out))
# ---> 21         out += self.shortcut(x)
#      22         out = F.relu(out)
#      23         return out
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     362                     "forward hooks should never return any values, but '{}'"
#     363                     "didn't return None".format(hook))
# --> 364         if len(self._backward_hooks) > 0:
#     365             var = result
#     366             while not isinstance(var, Variable):
#
# KeyboardInterrupt:

# %%
# learning_rate = 3e-6
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# TEST_Acc = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=False)
# LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  2.2263
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.1082
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015900
# epoch1, lossVariable containing:
#  1.9870
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8871
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007200
# epoch2, lossVariable containing:
#  1.8153
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7496
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018000
# epoch3, lossVariable containing:
#  1.6876
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6318
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011000
# epoch4, lossVariable containing:
#  1.5718
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5305
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012600
# epoch5, lossVariable containing:
#  1.4733
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4497
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019100
# epoch6, lossVariable containing:
#  1.3882
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3867
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013900
# epoch7, lossVariable containing:
#  1.3128
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3388
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008200
# epoch8, lossVariable containing:
#  1.2446
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2964
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023700
# epoch9, lossVariable containing:
#  1.1783
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2600
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013700
# epoch10, lossVariable containing:
#  1.1125
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2369
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001100
# epoch11, lossVariable containing:
#  1.0430
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2203
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009600
# epoch12, lossVariable containing:
#  0.9719
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2092
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008700
# epoch13, lossVariable containing:
#  0.9011
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2039
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014000
# epoch14, lossVariable containing:
#  0.8305
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.1978
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015500
# epoch15, lossVariable containing:
#  0.7565
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2043
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018500
# epoch16, lossVariable containing:
#  0.6882
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2211
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013000
# epoch17, lossVariable containing:
#  0.6184
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2256
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018500
# epoch18, lossVariable containing:
#  0.5522
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2390
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015100
# epoch19, lossVariable containing:
#  0.4882
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2584
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011800
# epoch20, lossVariable containing:
#  0.4298
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2925
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005700
# epoch21, lossVariable containing:
#  0.3760
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2894
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010600
# epoch22, lossVariable containing:
#  0.3308
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3010
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-feaee199a120> in <module>()
#       7 TEST_Acc = np.zeros([1, max_epoch])
#       8 optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=False)
# ----> 9 LOSS, Test_LOSS, Test_Acc= cifartrain()
#
# <ipython-input-20-337c8a4f0bfd> in cifartrain()
#      18             loss = criterion(outputs, labels)
#      19             loss.backward()
# ---> 20             optimizer.step()
#      21             running_loss += loss
#      22
#
# ~/OurAdam.py in step(self, closure)
#      68                 lr_decay = group['lr_decay']
#      69
# ---> 70                 state = self.state[p]
#      71
#      72                 # State initialization
#
# KeyboardInterrupt:

# %%
learning_rate = 1e-4
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.1, amsgrad=False)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  1.3574
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.0729
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005200
# epoch1, lossVariable containing:
#  0.9455
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.8893
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000200
# epoch2, lossVariable containing:
#  0.7811
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7924
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011000
# epoch3, lossVariable containing:
#  0.6825
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7339
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010000
# epoch4, lossVariable containing:
#  0.6183
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6886
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001900
# epoch5, lossVariable containing:
#  0.5697
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6543
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014900
# epoch6, lossVariable containing:
#  0.5302
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6443
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023300
# epoch7, lossVariable containing:
#  0.5010
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6009
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011800
# epoch8, lossVariable containing:
#  0.4761
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.5977
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017800
# epoch9, lossVariable containing:
#  0.4550
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6342
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007800
# epoch10, lossVariable containing:
#  0.4380
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.5946
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020200
# epoch11, lossVariable containing:
#  0.4266
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6087
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016400
# epoch12, lossVariable containing:
#  0.4131
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6406
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005400
# epoch13, lossVariable containing:
#  0.4044
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018700
# epoch14, lossVariable containing:
#  0.4022
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6205
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020800
# epoch15, lossVariable containing:
#  0.3989
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6297
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019400
# epoch16, lossVariable containing:
#  0.3986
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6332
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017600
# epoch17, lossVariable containing:
#  0.4067
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6339
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024100
# epoch18, lossVariable containing:
#  0.4097
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6451
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024300
# epoch19, lossVariable containing:
#  0.4152
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6660
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024500
# epoch20, lossVariable containing:
#  0.4247
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6579
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006600
# epoch21, lossVariable containing:
#  0.4300
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6807
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025100
# epoch22, lossVariable containing:
#  0.4441
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6666
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010200
# epoch23, lossVariable containing:
#  0.4526
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7116
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020700
# epoch24, lossVariable containing:
#  0.4656
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6951
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008900
# epoch25, lossVariable containing:
#  0.4709
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7103
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001000
# epoch26, lossVariable containing:
#  0.4722
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.6997
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010300
# epoch27, lossVariable containing:
#  0.4801
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7293
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023500
# epoch28, lossVariable containing:
#  0.4755
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7113
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009600
# epoch29, lossVariable containing:
#  0.4816
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7230
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004200
# epoch30, lossVariable containing:
#  0.4803
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7133
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009900
# epoch31, lossVariable containing:
#  0.4778
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7167
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007100
# epoch32, lossVariable containing:
#  0.4775
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  0.7263
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-b0d12b378347> in <module>()
#       7 TEST_Acc = np.zeros([1, max_epoch])
#       8 optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.1, amsgrad=False)
# ----> 9 LOSS, Test_LOSS, Test_Acc= cifartrain()
#
# <ipython-input-20-337c8a4f0bfd> in cifartrain()
#       3
#       4         running_loss = 0.0
# ----> 5         for i, data in enumerate(trainloader, 0):
#       6         # get the inputs
#       7             inputs, labels = data
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     257         if self.num_workers == 0:  # same-process loading
#     258             indices = next(self.sample_iter)  # may raise StopIteration
# --> 259             batch = self.collate_fn([self.dataset[i] for i in indices])
#     260             if self.pin_memory:
#     261                 batch = pin_memory_batch(batch)
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     257         if self.num_workers == 0:  # same-process loading
#     258             indices = next(self.sample_iter)  # may raise StopIteration
# --> 259             batch = self.collate_fn([self.dataset[i] for i in indices])
#     260             if self.pin_memory:
#     261                 batch = pin_memory_batch(batch)
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torchvision/datasets/cifar.py in __getitem__(self, index)
#     120
#     121         if self.transform is not None:
# --> 122             img = self.transform(img)
#     123
#     124         if self.target_transform is not None:
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      40     def __call__(self, img):
#      41         for t in self.transforms:
# ---> 42             img = t(img)
#      43         return img
#      44
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#      59             Tensor: Converted image.
#      60         """
# ---> 61         return F.to_tensor(pic)
#      62
#      63
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#      61         img = torch.from_numpy(np.array(pic, np.int16, copy=False))
#      62     else:
# ---> 63         img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
#      64     # PIL image mode: 1, L, P, I, F, RGB, YCbCr, RGBA, CMYK
#      65     if pic.mode == 'YCbCr':
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/PIL/Image.py in tobytes(self, encoder_name, *args)
#     726         e.setimage(self.im)
#     727
# --> 728         bufsize = max(65536, self.size[0] * 4)  # see RawEncode.c
#     729
#     730         data = []
#
# KeyboardInterrupt:

# %%
learning_rate = 1e-6
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=False)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  2.2795
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2377
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011800
# epoch1, lossVariable containing:
#  2.2019
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.1625
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005000
# epoch2, lossVariable containing:
#  2.1280
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.0905
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015000
# epoch3, lossVariable containing:
#  2.0573
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.0203
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021000
# epoch4, lossVariable containing:
#  1.9854
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9467
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024400
# epoch5, lossVariable containing:
#  1.9110
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8742
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023100
# epoch6, lossVariable containing:
#  1.8441
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8149
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021200
# epoch7, lossVariable containing:
#  1.7902
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7663
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014200
# epoch8, lossVariable containing:
#  1.7445
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7246
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001300
# epoch9, lossVariable containing:
#  1.7054
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6884
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014100
# epoch10, lossVariable containing:
#  1.6707
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6550
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001800
# epoch11, lossVariable containing:
#  1.6353
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6240
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011300
# epoch12, lossVariable containing:
#  1.6010
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5925
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018600
# epoch13, lossVariable containing:
#  1.5686
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5631
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001000
# epoch14, lossVariable containing:
#  1.5372
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5345
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012500
# epoch15, lossVariable containing:
#  1.5059
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5083
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018600
# epoch16, lossVariable containing:
#  1.4748
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4838
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025300
# epoch17, lossVariable containing:
#  1.4463
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4608
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008700
# epoch18, lossVariable containing:
#  1.4193
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4393
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015200
# epoch19, lossVariable containing:
#  1.3907
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4205
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025400
# epoch20, lossVariable containing:
#  1.3654
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4014
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007000
# epoch21, lossVariable containing:
#  1.3369
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3842
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013300
# epoch22, lossVariable containing:
#  1.3135
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3690
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017900
# epoch23, lossVariable containing:
#  1.2874
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3546
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022800
# epoch24, lossVariable containing:
#  1.2668
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3411
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003200
# epoch25, lossVariable containing:
#  1.2394
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3293
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007600
# epoch26, lossVariable containing:
#  1.2173
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3182
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013300
# epoch27, lossVariable containing:
#  1.1912
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3083
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015500
# epoch28, lossVariable containing:
#  1.1679
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2967
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021000
# epoch29, lossVariable containing:
#  1.1441
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2900
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001100
# epoch30, lossVariable containing:
#  1.1202
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2786
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006200
# epoch31, lossVariable containing:
#  1.0967
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2725
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007800
# epoch32, lossVariable containing:
#  1.0713
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2649
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010200
# epoch33, lossVariable containing:
#  1.0474
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2595
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014000
# epoch34, lossVariable containing:
#  1.0200
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2538
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019000
# epoch35, lossVariable containing:
#  0.9971
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2510
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020300
# epoch36, lossVariable containing:
#  0.9743
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2501
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023500
# epoch37, lossVariable containing:
#  0.9482
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2437
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023500
# epoch38, lossVariable containing:
#  0.9211
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2456
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025100
# epoch39, lossVariable containing:
#  0.8988
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2406
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025300
# epoch40, lossVariable containing:
#  0.8714
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2406
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001700
# epoch41, lossVariable containing:
#  0.8477
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2434
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001100
# epoch42, lossVariable containing:
#  0.8223
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2421
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000100
# epoch43, lossVariable containing:
#  0.7959
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2438
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000900
# epoch44, lossVariable containing:
#  0.7743
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2556
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch45, lossVariable containing:
#  0.7469
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2505
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002400
# epoch46, lossVariable containing:
#  0.7223
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2538
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001700
# epoch47, lossVariable containing:
#  0.6959
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2531
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000500
# epoch48, lossVariable containing:
#  0.6727
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2565
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001600
# epoch49, lossVariable containing:
#  0.6499
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2617
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000100
# Finished Training

# %%
sio.savemat('adam_res_gen.mat',{'loss':LOSS, 'test_loss':Test_LOSS, 'test_acc':Test_Acc})

# %% [markdown]
# Adam temporarily uses the above result

# %%
max_epoch=100

# %%
learning_rate = 9e-7
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=False)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  2.3181
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2909
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024600
# epoch1, lossVariable containing:
#  2.2621
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2322
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007900
# epoch2, lossVariable containing:
#  2.1859
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.1406
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011600
# epoch3, lossVariable containing:
#  2.0908
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.0543
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000900
# epoch4, lossVariable containing:
#  2.0177
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9925
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025100
# epoch5, lossVariable containing:
#  1.9596
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9384
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020800
# epoch6, lossVariable containing:
#  1.9076
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8896
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018300
# epoch7, lossVariable containing:
#  1.8610
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8453
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012900
# epoch8, lossVariable containing:
#  1.8191
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8037
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000600
# epoch9, lossVariable containing:
#  1.7784
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7656
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014500
# epoch10, lossVariable containing:
#  1.7407
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7274
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002900
# epoch11, lossVariable containing:
#  1.7034
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6901
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015800
# epoch12, lossVariable containing:
#  1.6656
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6546
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025400
# epoch13, lossVariable containing:
#  1.6297
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6208
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008100
# epoch14, lossVariable containing:
#  1.5964
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5911
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017600
# epoch15, lossVariable containing:
#  1.5627
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5631
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023900
# epoch16, lossVariable containing:
#  1.5316
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5373
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005100
# epoch17, lossVariable containing:
#  1.5048
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5116
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013200
# epoch18, lossVariable containing:
#  1.4746
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4881
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021800
# epoch19, lossVariable containing:
#  1.4482
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4666
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005700
# epoch20, lossVariable containing:
#  1.4216
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4458
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013500
# epoch21, lossVariable containing:
#  1.3957
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4263
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021200
# epoch22, lossVariable containing:
#  1.3689
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4087
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005200
# epoch23, lossVariable containing:
#  1.3437
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3914
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013200
# epoch24, lossVariable containing:
#  1.3192
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3750
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018500
# epoch25, lossVariable containing:
#  1.2958
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3610
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023500
# epoch26, lossVariable containing:
#  1.2719
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3464
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006200
# epoch27, lossVariable containing:
#  1.2482
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3344
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010400
# epoch28, lossVariable containing:
#  1.2255
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3210
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012600
# epoch29, lossVariable containing:
#  1.2013
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3094
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016300
# epoch30, lossVariable containing:
#  1.1793
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2982
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021300
# epoch31, lossVariable containing:
#  1.1551
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2886
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025300
# epoch32, lossVariable containing:
#  1.1319
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2782
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006900
# epoch33, lossVariable containing:
#  1.1092
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2712
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007200
# epoch34, lossVariable containing:
#  1.0849
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2632
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012900
# epoch35, lossVariable containing:
#  1.0630
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2539
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016300
# epoch36, lossVariable containing:
#  1.0371
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2497
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019100
# epoch37, lossVariable containing:
#  1.0137
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2432
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021000
# epoch38, lossVariable containing:
#  0.9915
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2440
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021600
# epoch39, lossVariable containing:
#  0.9653
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2381
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025200
# epoch40, lossVariable containing:
#  0.9423
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2354
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002200
# epoch41, lossVariable containing:
#  0.9191
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2334
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003600
# epoch42, lossVariable containing:
#  0.8964
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2347
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002200
# epoch43, lossVariable containing:
#  0.8717
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2328
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003100
# epoch44, lossVariable containing:
#  0.8492
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2328
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004000
# epoch45, lossVariable containing:
#  0.8258
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2329
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004100
# epoch46, lossVariable containing:
#  0.8030
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2396
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002500
# epoch47, lossVariable containing:
#  0.7788
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2383
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006000
# epoch48, lossVariable containing:
#  0.7542
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2413
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004800
# epoch49, lossVariable containing:
#  0.7296
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2462
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003500
# epoch50, lossVariable containing:
#  0.7061
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2496
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025100
# epoch51, lossVariable containing:
#  0.6844
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2515
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004800
# epoch52, lossVariable containing:
#  0.6601
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-6e8268809a3b> in <module>()
#       7 TEST_Acc = np.zeros([1, max_epoch])
#       8 optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=False)
# ----> 9 LOSS, Test_LOSS, Test_Acc= cifartrain()
#
# <ipython-input-20-337c8a4f0bfd> in cifartrain()
#      24         LOSS[0, epoch] = running_loss/(i+1)
#      25         # Test every epoch
# ---> 26         Test_LOSS[0, epoch], TEST_Acc[0, epoch] = cifartest()
#      27
#      28     print('Finished Training')
#
# <ipython-input-19-1c840884edf3> in cifartest()
#       5         test_loss = 0
#       6
# ----> 7         for batch_idx, (inputs, targets) in enumerate(testloader):
#       8             inputs, targets = Variable(inputs, volatile=True),Variable(targets, volatile=True)
#       9             inputs, targets = inputs.cuda(), targets.cuda()
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     257         if self.num_workers == 0:  # same-process loading
#     258             indices = next(self.sample_iter)  # may raise StopIteration
# --> 259             batch = self.collate_fn([self.dataset[i] for i in indices])
#     260             if self.pin_memory:
#     261                 batch = pin_memory_batch(batch)
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     257         if self.num_workers == 0:  # same-process loading
#     258             indices = next(self.sample_iter)  # may raise StopIteration
# --> 259             batch = self.collate_fn([self.dataset[i] for i in indices])
#     260             if self.pin_memory:
#     261                 batch = pin_memory_batch(batch)
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torchvision/datasets/cifar.py in __getitem__(self, index)
#     117         # doing this so that it is consistent with all other datasets
#     118         # to return a PIL Image
# --> 119         img = Image.fromarray(img)
#     120
#     121         if self.transform is not None:
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2444     if strides is not None:
#    2445         if hasattr(obj, 'tobytes'):
# -> 2446             obj = obj.tobytes()
#    2447         else:
#    2448             obj = obj.tostring()
#
# KeyboardInterrupt:

# %%
learning_rate = 8e-7
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=False)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  2.2920
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2725
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003200
# epoch1, lossVariable containing:
#  2.2521
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2337
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014700
# epoch2, lossVariable containing:
#  2.2108
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.1868
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010200
# epoch3, lossVariable containing:
#  2.1541
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.1198
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013100
# epoch4, lossVariable containing:
#  2.0802
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.0451
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014200
# epoch5, lossVariable containing:
#  2.0127
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9846
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005600
# epoch6, lossVariable containing:
#  1.9548
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9295
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025400
# epoch7, lossVariable containing:
#  1.8994
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8755
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022200
# epoch8, lossVariable containing:
#  1.8489
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8275
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013700
# epoch9, lossVariable containing:
#  1.8031
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7869
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002000
# epoch10, lossVariable containing:
#  1.7650
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7517
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015200
# epoch11, lossVariable containing:
#  1.7321
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7203
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001000
# epoch12, lossVariable containing:
#  1.7001
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6901
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010300
# epoch13, lossVariable containing:
#  1.6688
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6609
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020500
# epoch14, lossVariable containing:
#  1.6411
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6326
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003000
# epoch15, lossVariable containing:
#  1.6108
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6065
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011700
# epoch16, lossVariable containing:
#  1.5849
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5812
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017800
# epoch17, lossVariable containing:
#  1.5581
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5566
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001100
# epoch18, lossVariable containing:
#  1.5330
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5347
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009000
# epoch19, lossVariable containing:
#  1.5071
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5122
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016400
# epoch20, lossVariable containing:
#  1.4823
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4909
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001300
# epoch21, lossVariable containing:
#  1.4597
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4714
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004600
# epoch22, lossVariable containing:
#  1.4366
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4527
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014300
# epoch23, lossVariable containing:
#  1.4129
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4338
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023700
# epoch24, lossVariable containing:
#  1.3914
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4175
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002700
# epoch25, lossVariable containing:
#  1.3705
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4016
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010100
# epoch26, lossVariable containing:
#  1.3490
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3864
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015400
# epoch27, lossVariable containing:
#  1.3299
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3721
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018400
# epoch28, lossVariable containing:
#  1.3113
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3588
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001100
# epoch29, lossVariable containing:
#  1.2906
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3462
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003200
# epoch30, lossVariable containing:
#  1.2707
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3339
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013800
# epoch31, lossVariable containing:
#  1.2497
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3223
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018100
# epoch32, lossVariable containing:
#  1.2335
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3126
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022300
# epoch33, lossVariable containing:
#  1.2118
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3028
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025300
# epoch34, lossVariable containing:
#  1.1927
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2934
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004900
# epoch35, lossVariable containing:
#  1.1730
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2844
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007200
# epoch36, lossVariable containing:
#  1.1549
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2778
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008800
# epoch37, lossVariable containing:
#  1.1336
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2700
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011300
# epoch38, lossVariable containing:
#  1.1149
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2634
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014900
# epoch39, lossVariable containing:
#  1.0960
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2555
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020700
# epoch40, lossVariable containing:
#  1.0756
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2533
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020300
# epoch41, lossVariable containing:
#  1.0549
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2455
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023600
# epoch42, lossVariable containing:
#  1.0350
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2432
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001900
# epoch43, lossVariable containing:
#  1.0137
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2387
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001800
# epoch44, lossVariable containing:
#  0.9907
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2355
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007900
# epoch45, lossVariable containing:
#  0.9727
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2303
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001900
# epoch46, lossVariable containing:
#  0.9535
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2308
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007700
# epoch47, lossVariable containing:
#  0.9340
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2282
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005200
# epoch48, lossVariable containing:
#  0.9120
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2263
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007500
# epoch49, lossVariable containing:
#  0.8894
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2259
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009800
# epoch50, lossVariable containing:
#  0.8710
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2234
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010800
# epoch51, lossVariable containing:
#  0.8500
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2291
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007000
# epoch52, lossVariable containing:
#  0.8278
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2285
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009200
# epoch53, lossVariable containing:
#  0.8098
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2276
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008700
# epoch54, lossVariable containing:
#  0.7854
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2322
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009800
# epoch55, lossVariable containing:
#  0.7669
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2325
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010900
# epoch56, lossVariable containing:
#  0.7472
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2370
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010200
# epoch57, lossVariable containing:
#  0.7273
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2345
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011100
# epoch58, lossVariable containing:
#  0.7061
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2389
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009000
# epoch59, lossVariable containing:
#  0.6895
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2406
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011200
# epoch60, lossVariable containing:
#  0.6673
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2464
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009200
# epoch61, lossVariable containing:
#  0.6491
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2478
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008700
# epoch62, lossVariable containing:
#  0.6287
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2520
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010200
# epoch63, lossVariable containing:
#  0.6096
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2497
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012400
# epoch64, lossVariable containing:
#  0.5909
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2557
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008800
# epoch65, lossVariable containing:
#  0.5735
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2584
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011300
# epoch66, lossVariable containing:
#  0.5561
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2653
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009600
# epoch67, lossVariable containing:
#  0.5343
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2639
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006700
# epoch68, lossVariable containing:
#  0.5167
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2685
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006100
# epoch69, lossVariable containing:
#  0.4979
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2649
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011300
# epoch70, lossVariable containing:
#  0.4845
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2769
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005100
# epoch71, lossVariable containing:
#  0.4658
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2756
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006900
# epoch72, lossVariable containing:
#  0.4512
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2794
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004200
# epoch73, lossVariable containing:
#  0.4345
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2905
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004000
# epoch74, lossVariable containing:
#  0.4218
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2877
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000600
# epoch75, lossVariable containing:
#  0.4036
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2898
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001300
# epoch76, lossVariable containing:
#  0.3912
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2895
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001900
# epoch77, lossVariable containing:
#  0.3785
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2958
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002700
# epoch78, lossVariable containing:
#  0.3675
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3000
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000200
# epoch79, lossVariable containing:
#  0.3495
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3026
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000500
# epoch80, lossVariable containing:
#  0.3412
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3051
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025000
# epoch81, lossVariable containing:
#  0.3278
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3047
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001000
# epoch82, lossVariable containing:
#  0.3165
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3075
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000700
# epoch83, lossVariable containing:
#  0.3056
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3128
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001200
# epoch84, lossVariable containing:
#  0.2971
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3118
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003200
# epoch85, lossVariable containing:
#  0.2882
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3197
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024400
# epoch86, lossVariable containing:
#  0.2802
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3183
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024500
# epoch87, lossVariable containing:
#  0.2715
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3240
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022900
# epoch88, lossVariable containing:
#  0.2603
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3266
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024600
# epoch89, lossVariable containing:
#  0.2536
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3342
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024800
# epoch90, lossVariable containing:
#  0.2471
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3275
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024900
# epoch91, lossVariable containing:
#  0.2401
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3307
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024200
# epoch92, lossVariable containing:
#  0.2323
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3320
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023900
# epoch93, lossVariable containing:
#  0.2262
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3329
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022200
# epoch94, lossVariable containing:
#  0.2212
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3350
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001200
# epoch95, lossVariable containing:
#  0.2138
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3335
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022500
# epoch96, lossVariable containing:
#  0.2108
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3498
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019700
# epoch97, lossVariable containing:
#  0.2047
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3456
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025400
# epoch98, lossVariable containing:
#  0.2006
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3418
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025200
# epoch99, lossVariable containing:
#  0.1959
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3371
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024900
# Finished Training

# %%
sio.savemat('adam_res_gen8.mat',{'loss':LOSS, 'test_loss':Test_LOSS, 'test_acc':Test_Acc})

# %% [markdown]
# ##  adam's best

# %%
max_epoch=100

# %%
learning_rate = 7e-7
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=False)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  2.2980
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2682
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013400
# epoch1, lossVariable containing:
#  2.2383
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2103
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012300
# epoch2, lossVariable containing:
#  2.1806
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.1541
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020500
# epoch3, lossVariable containing:
#  2.1258
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.1008
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006400
# epoch4, lossVariable containing:
#  2.0722
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.0476
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015800
# epoch5, lossVariable containing:
#  2.0178
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9921
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013200
# epoch6, lossVariable containing:
#  1.9632
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9389
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002500
# epoch7, lossVariable containing:
#  1.9119
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8922
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017800
# epoch8, lossVariable containing:
#  1.8696
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8526
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002600
# epoch9, lossVariable containing:
#  1.8316
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8189
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013600
# epoch10, lossVariable containing:
#  1.7999
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7895
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024600
# epoch11, lossVariable containing:
#  1.7722
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7627
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009300
# epoch12, lossVariable containing:
#  1.7461
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7380
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021300
# epoch13, lossVariable containing:
#  1.7192
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7140
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002700
# epoch14, lossVariable containing:
#  1.6959
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6904
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009200
# epoch15, lossVariable containing:
#  1.6701
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6668
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018800
# epoch16, lossVariable containing:
#  1.6462
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6441
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002300
# epoch17, lossVariable containing:
#  1.6208
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6193
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012400
# epoch18, lossVariable containing:
#  1.5937
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5961
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020200
# epoch19, lossVariable containing:
#  1.5677
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5718
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001900
# epoch20, lossVariable containing:
#  1.5423
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5497
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010300
# epoch21, lossVariable containing:
#  1.5191
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5290
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015800
# epoch22, lossVariable containing:
#  1.4958
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5094
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024500
# epoch23, lossVariable containing:
#  1.4744
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4928
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004700
# epoch24, lossVariable containing:
#  1.4554
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4766
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011000
# epoch25, lossVariable containing:
#  1.4333
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4607
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015700
# epoch26, lossVariable containing:
#  1.4181
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4461
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019900
# epoch27, lossVariable containing:
#  1.3977
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4323
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022400
# epoch28, lossVariable containing:
#  1.3802
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4184
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002700
# epoch29, lossVariable containing:
#  1.3628
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4053
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008900
# epoch30, lossVariable containing:
#  1.3457
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3930
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013900
# epoch31, lossVariable containing:
#  1.3286
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3822
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017900
# epoch32, lossVariable containing:
#  1.3122
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3701
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020900
# epoch33, lossVariable containing:
#  1.2955
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3581
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001700
# epoch34, lossVariable containing:
#  1.2773
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3483
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004000
# epoch35, lossVariable containing:
#  1.2615
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3387
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006500
# epoch36, lossVariable containing:
#  1.2447
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3298
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011700
# epoch37, lossVariable containing:
#  1.2273
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3202
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014500
# epoch38, lossVariable containing:
#  1.2106
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3123
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018800
# epoch39, lossVariable containing:
#  1.1946
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3027
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023400
# epoch40, lossVariable containing:
#  1.1759
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2965
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025500
# epoch41, lossVariable containing:
#  1.1578
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2890
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002200
# epoch42, lossVariable containing:
#  1.1413
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2809
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007900
# epoch43, lossVariable containing:
#  1.1232
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2753
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009500
# epoch44, lossVariable containing:
#  1.1072
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2677
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015500
# epoch45, lossVariable containing:
#  1.0895
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2661
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016700
# epoch46, lossVariable containing:
#  1.0711
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2579
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019500
# epoch47, lossVariable containing:
#  1.0526
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2575
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019700
# epoch48, lossVariable containing:
#  1.0346
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2500
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024200
# epoch49, lossVariable containing:
#  1.0179
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2465
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001700
# epoch50, lossVariable containing:
#  0.9993
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2464
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023500
# epoch51, lossVariable containing:
#  0.9822
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2394
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000100
# epoch52, lossVariable containing:
#  0.9636
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2379
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003600
# epoch53, lossVariable containing:
#  0.9472
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2361
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004500
# epoch54, lossVariable containing:
#  0.9272
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2378
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003400
# epoch55, lossVariable containing:
#  0.9088
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2324
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005500
# epoch56, lossVariable containing:
#  0.8891
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2318
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005800
# epoch57, lossVariable containing:
#  0.8738
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2316
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006900
# epoch58, lossVariable containing:
#  0.8527
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2375
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006700
# epoch59, lossVariable containing:
#  0.8372
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2309
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005700
# epoch60, lossVariable containing:
#  0.8181
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2303
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006800
# epoch61, lossVariable containing:
#  0.7995
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2296
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007300
# epoch62, lossVariable containing:
#  0.7838
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2367
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004200
# epoch63, lossVariable containing:
#  0.7656
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2355
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005000
# epoch64, lossVariable containing:
#  0.7480
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2360
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007300
# epoch65, lossVariable containing:
#  0.7305
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2383
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003500
# epoch66, lossVariable containing:
#  0.7128
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2406
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004300
# epoch67, lossVariable containing:
#  0.6951
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2390
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008500
# epoch68, lossVariable containing:
#  0.6778
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2453
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007300
# epoch69, lossVariable containing:
#  0.6598
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2460
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004700
# epoch70, lossVariable containing:
#  0.6413
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2461
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003400
# epoch71, lossVariable containing:
#  0.6271
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2498
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004900
# epoch72, lossVariable containing:
#  0.6075
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2533
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005700
# epoch73, lossVariable containing:
#  0.5929
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2532
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-2c66b7516ec5> in <module>()
#       7 TEST_Acc = np.zeros([1, max_epoch])
#       8 optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=False)
# ----> 9 LOSS, Test_LOSS, Test_Acc= cifartrain()
#
# <ipython-input-7-337c8a4f0bfd> in cifartrain()
#       8             inputs = Variable(inputs)
#       9             labels = Variable(labels)
# ---> 10             inputs = inputs.cuda()
#      11             labels = labels.cuda()
#      12
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/autograd/variable.py in cuda(self, device, async)
#     296
#     297     def cuda(self, device=None, async=False):
# --> 298         return CudaTransfer.apply(self, device, async)
#     299
#     300     def cpu(self):
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, device, async)
#     199             return i.cuda(device, async=async)
#     200         else:
# --> 201             return i.cuda(async=async)
#     202
#     203     @staticmethod
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/_utils.py in _cuda(self, device, async)
#      67         else:
#      68             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 69             return new_type(self.size()).copy_(self, async)
#      70
#      71
#
# KeyboardInterrupt:

# %%
sio.savemat('adam_res_gen77.mat',{'loss':LOSS, 'test_loss':Test_LOSS, 'test_acc':Test_Acc})

# %% [markdown]
# AmsGrad

# %%
learning_rate = 1e-6
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=True)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  2.3233
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2876
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004000
# epoch1, lossVariable containing:
#  2.2440
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.1998
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024000
# epoch2, lossVariable containing:
#  2.1409
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.0872
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006500
# epoch3, lossVariable containing:
#  2.0406
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.0027
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014400
# epoch4, lossVariable containing:
#  1.9683
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9418
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018500
# epoch5, lossVariable containing:
#  1.9108
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8865
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015500
# epoch6, lossVariable containing:
#  1.8542
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8264
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013400
# epoch7, lossVariable containing:
#  1.7940
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7695
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006700
# epoch8, lossVariable containing:
#  1.7445
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7239
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024100
# epoch9, lossVariable containing:
#  1.7004
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6839
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014800
# epoch10, lossVariable containing:
#  1.6606
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6468
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002000
# epoch11, lossVariable containing:
#  1.6227
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6105
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015700
# epoch12, lossVariable containing:
#  1.5865
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5752
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001600
# epoch13, lossVariable containing:
#  1.5496
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5431
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012600
# epoch14, lossVariable containing:
#  1.5147
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5129
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022200
# epoch15, lossVariable containing:
#  1.4821
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4865
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006200
# epoch16, lossVariable containing:
#  1.4522
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4620
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014500
# epoch17, lossVariable containing:
#  1.4244
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4398
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022000
# epoch18, lossVariable containing:
#  1.3977
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4193
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004600
# epoch19, lossVariable containing:
#  1.3728
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4005
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010700
# epoch20, lossVariable containing:
#  1.3474
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3830
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017800
# epoch21, lossVariable containing:
#  1.3220
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3653
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022900
# epoch22, lossVariable containing:
#  1.2984
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3493
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006200
# epoch23, lossVariable containing:
#  1.2754
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3354
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013000
# epoch24, lossVariable containing:
#  1.2517
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3217
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017100
# epoch25, lossVariable containing:
#  1.2286
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3082
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022600
# epoch26, lossVariable containing:
#  1.2081
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2964
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002400
# epoch27, lossVariable containing:
#  1.1868
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2863
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006000
# epoch28, lossVariable containing:
#  1.1639
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2731
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011200
# epoch29, lossVariable containing:
#  1.1429
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2642
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012600
# epoch30, lossVariable containing:
#  1.1208
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2552
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016900
# epoch31, lossVariable containing:
#  1.0984
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2476
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.021600
# epoch32, lossVariable containing:
#  1.0800
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2388
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023500
# epoch33, lossVariable containing:
#  1.0565
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2302
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004000
# epoch34, lossVariable containing:
#  1.0354
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2283
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002400
# epoch35, lossVariable containing:
#  1.0127
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2225
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005400
# epoch36, lossVariable containing:
#  0.9907
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2160
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008100
# epoch37, lossVariable containing:
#  0.9688
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2150
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008800
# epoch38, lossVariable containing:
#  0.9472
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2104
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012300
# epoch39, lossVariable containing:
#  0.9232
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2072
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011400
# epoch40, lossVariable containing:
#  0.9040
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2061
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013600
# epoch41, lossVariable containing:
#  0.8816
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2056
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011700
# epoch42, lossVariable containing:
#  0.8580
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2014
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016500
# epoch43, lossVariable containing:
#  0.8343
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2064
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015500
# epoch44, lossVariable containing:
#  0.8138
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2066
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015900
# epoch45, lossVariable containing:
#  0.7899
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2090
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016100
# epoch46, lossVariable containing:
#  0.7668
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2092
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013900
# epoch47, lossVariable containing:
#  0.7472
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2090
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016100
# epoch48, lossVariable containing:
#  0.7254
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2135
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017100
# epoch49, lossVariable containing:
#  0.7047
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2168
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015300
# Finished Training

# %%
sio.savemat('amsgrad_res_gen.mat',{'loss':LOSS, 'test_loss':Test_LOSS, 'test_acc':Test_Acc})

# %%
learning_rate = 8e-7
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=True)
LOSS, Test_LOSS, Test_Acc= cifartrain()
# Out:
# epoch0, lossVariable containing:
#  2.2992
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2770
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016400
# epoch1, lossVariable containing:
#  2.2550
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.2320
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006800
# epoch2, lossVariable containing:
#  2.2015
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.1676
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020900
# epoch3, lossVariable containing:
#  2.1247
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.0846
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.012700
# epoch4, lossVariable containing:
#  2.0461
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  2.0163
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020400
# epoch5, lossVariable containing:
#  1.9838
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9606
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010100
# epoch6, lossVariable containing:
#  1.9301
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.9086
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010100
# epoch7, lossVariable containing:
#  1.8788
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8596
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003500
# epoch8, lossVariable containing:
#  1.8325
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.8149
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020900
# epoch9, lossVariable containing:
#  1.7910
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7771
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008200
# epoch10, lossVariable containing:
#  1.7549
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7438
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018800
# epoch11, lossVariable containing:
#  1.7233
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.7134
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002100
# epoch12, lossVariable containing:
#  1.6927
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6833
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011600
# epoch13, lossVariable containing:
#  1.6622
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6537
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025400
# epoch14, lossVariable containing:
#  1.6313
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.6247
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.013300
# epoch15, lossVariable containing:
#  1.6021
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5969
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020000
# epoch16, lossVariable containing:
#  1.5711
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5698
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004400
# epoch17, lossVariable containing:
#  1.5423
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5446
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011500
# epoch18, lossVariable containing:
#  1.5159
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.5211
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018900
# epoch19, lossVariable containing:
#  1.4901
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4990
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000400
# epoch20, lossVariable containing:
#  1.4658
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4794
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008900
# epoch21, lossVariable containing:
#  1.4426
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4612
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015800
# epoch22, lossVariable containing:
#  1.4206
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4437
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020600
# epoch23, lossVariable containing:
#  1.3991
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4274
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002700
# epoch24, lossVariable containing:
#  1.3787
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.4121
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007200
# epoch25, lossVariable containing:
#  1.3579
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3977
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011900
# epoch26, lossVariable containing:
#  1.3390
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3851
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017900
# epoch27, lossVariable containing:
#  1.3190
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3720
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023600
# epoch28, lossVariable containing:
#  1.3006
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3594
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001700
# epoch29, lossVariable containing:
#  1.2831
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3480
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007100
# epoch30, lossVariable containing:
#  1.2645
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3382
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007900
# epoch31, lossVariable containing:
#  1.2468
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3289
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016700
# epoch32, lossVariable containing:
#  1.2284
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3196
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017500
# epoch33, lossVariable containing:
#  1.2108
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3082
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022100
# epoch34, lossVariable containing:
#  1.1950
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3006
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.025000
# epoch35, lossVariable containing:
#  1.1756
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2934
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001900
# epoch36, lossVariable containing:
#  1.1595
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2855
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006500
# epoch37, lossVariable containing:
#  1.1404
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2786
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011600
# epoch38, lossVariable containing:
#  1.1258
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2730
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011900
# epoch39, lossVariable containing:
#  1.1052
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2672
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015600
# epoch40, lossVariable containing:
#  1.0880
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2624
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019600
# epoch41, lossVariable containing:
#  1.0706
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2565
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019800
# epoch42, lossVariable containing:
#  1.0511
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2530
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018700
# epoch43, lossVariable containing:
#  1.0347
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2476
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024600
# epoch44, lossVariable containing:
#  1.0162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2447
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000800
# epoch45, lossVariable containing:
#  0.9983
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2399
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.003100
# epoch46, lossVariable containing:
#  0.9783
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2380
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006200
# epoch47, lossVariable containing:
#  0.9598
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2369
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006600
# epoch48, lossVariable containing:
#  0.9402
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2358
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007800
# epoch49, lossVariable containing:
#  0.9236
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2326
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007200
# epoch50, lossVariable containing:
#  0.9035
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2320
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009600
# epoch51, lossVariable containing:
#  0.8847
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2324
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006600
# epoch52, lossVariable containing:
#  0.8624
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2322
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008000
# epoch53, lossVariable containing:
#  0.8468
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2329
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011700
# epoch54, lossVariable containing:
#  0.8274
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2345
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.010600
# epoch55, lossVariable containing:
#  0.8083
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2368
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009200
# epoch56, lossVariable containing:
#  0.7890
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2365
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011600
# epoch57, lossVariable containing:
#  0.7699
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2425
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008600
# epoch58, lossVariable containing:
#  0.7536
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2422
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.008800
# epoch59, lossVariable containing:
#  0.7328
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2442
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009100
# epoch60, lossVariable containing:
#  0.7160
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2480
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.011000
# epoch61, lossVariable containing:
#  0.6951
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2521
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.009100
# epoch62, lossVariable containing:
#  0.6779
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2546
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007900
# epoch63, lossVariable containing:
#  0.6593
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2563
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006400
# epoch64, lossVariable containing:
#  0.6436
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2598
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006600
# epoch65, lossVariable containing:
#  0.6233
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2656
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006400
# epoch66, lossVariable containing:
#  0.6050
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2621
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.007600
# epoch67, lossVariable containing:
#  0.5878
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2739
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.004600
# epoch68, lossVariable containing:
#  0.5702
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2718
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005000
# epoch69, lossVariable containing:
#  0.5505
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2803
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.006100
# epoch70, lossVariable containing:
#  0.5324
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2847
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.005500
# epoch71, lossVariable containing:
#  0.5206
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2870
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002000
# epoch72, lossVariable containing:
#  0.5003
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2911
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.001100
# epoch73, lossVariable containing:
#  0.4858
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2922
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.000900
# epoch74, lossVariable containing:
#  0.4699
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.2945
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.002500
# epoch75, lossVariable containing:
#  0.4598
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3045
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024100
# epoch76, lossVariable containing:
#  0.4387
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3102
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.024800
# epoch77, lossVariable containing:
#  0.4260
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3152
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020100
# epoch78, lossVariable containing:
#  0.4119
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3168
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.023200
# epoch79, lossVariable containing:
#  0.3978
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3189
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.022400
# epoch80, lossVariable containing:
#  0.3840
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3227
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019600
# epoch81, lossVariable containing:
#  0.3745
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3241
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020800
# epoch82, lossVariable containing:
#  0.3599
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3349
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.018800
# epoch83, lossVariable containing:
#  0.3480
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3361
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019900
# epoch84, lossVariable containing:
#  0.3392
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3384
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020500
# epoch85, lossVariable containing:
#  0.3244
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3417
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020100
# epoch86, lossVariable containing:
#  0.3167
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3414
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.020200
# epoch87, lossVariable containing:
#  0.3033
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3480
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016400
# epoch88, lossVariable containing:
#  0.2961
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3515
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015900
# epoch89, lossVariable containing:
#  0.2835
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3547
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019100
# epoch90, lossVariable containing:
#  0.2797
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3560
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016600
# epoch91, lossVariable containing:
#  0.2698
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3602
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015200
# epoch92, lossVariable containing:
#  0.2625
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3639
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.017700
# epoch93, lossVariable containing:
#  0.2533
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3634
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.019600
# epoch94, lossVariable containing:
#  0.2473
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3616
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016300
# epoch95, lossVariable containing:
#  0.2410
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3740
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015200
# epoch96, lossVariable containing:
#  0.2354
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3727
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015700
# epoch97, lossVariable containing:
#  0.2276
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3662
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.016600
# epoch98, lossVariable containing:
#  0.2220
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3785
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.014600
# epoch99, lossVariable containing:
#  0.2126
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# test loss:Variable containing:
#  1.3811
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Accuracy of the network on the 10000 test images: 0.015200
# Finished Training

# %%
sio.savemat('amsgrad_res_gen8.mat',{'loss':LOSS, 'test_loss':Test_LOSS, 'test_acc':Test_Acc})

# %% [markdown]
# ## amsgrad's best

# %%
learning_rate = 7e-7
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
TEST_Acc = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, weight_decay=0.3, amsgrad=True)
LOSS, Test_LOSS, Test_Acc= cifartrain()

# %%
sio.savemat('amsgrad_res_gen77.mat',{'loss':LOSS, 'test_loss':Test_LOSS, 'test_acc':Test_Acc})

# %% [markdown]
# ### Longer Training

# %%
max_epoch=100

# %%
learning_rate = 6e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, amsgrad=True)
LOSS, Test_LOSS= cifartrain()
sio.savemat('amsgrad_res.mat',{'loss':LOSS})
# Out:
# epoch0, lossVariable containing:
#  1.3702
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch1, lossVariable containing:
#  0.9068
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch2, lossVariable containing:
#  0.6575
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch3, lossVariable containing:
#  0.4340
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch4, lossVariable containing:
#  0.2329
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch5, lossVariable containing:
#  0.1203
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch6, lossVariable containing:
# 1.00000e-02 *
#   5.4533
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch7, lossVariable containing:
# 1.00000e-02 *
#   2.4356
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch8, lossVariable containing:
# 1.00000e-03 *
#   9.6874
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch9, lossVariable containing:
# 1.00000e-03 *
#   4.9833
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch10, lossVariable containing:
# 1.00000e-03 *
#   3.4243
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch11, lossVariable containing:
# 1.00000e-03 *
#   2.7807
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch12, lossVariable containing:
# 1.00000e-03 *
#   2.2867
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch13, lossVariable containing:
# 1.00000e-03 *
#   1.9063
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch14, lossVariable containing:
# 1.00000e-03 *
#   1.7377
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch15, lossVariable containing:
# 1.00000e-03 *
#   1.5644
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch16, lossVariable containing:
# 1.00000e-03 *
#   1.3713
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch17, lossVariable containing:
# 1.00000e-03 *
#   1.3184
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch18, lossVariable containing:
# 1.00000e-03 *
#   1.2337
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch19, lossVariable containing:
# 1.00000e-03 *
#   1.1322
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch20, lossVariable containing:
# 1.00000e-03 *
#   1.0818
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch21, lossVariable containing:
# 1.00000e-04 *
#   9.8515
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch22, lossVariable containing:
# 1.00000e-04 *
#   9.3573
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch23, lossVariable containing:
# 1.00000e-04 *
#   9.2066
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch24, lossVariable containing:
# 1.00000e-04 *
#   8.4617
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch25, lossVariable containing:
# 1.00000e-04 *
#   7.8053
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch26, lossVariable containing:
# 1.00000e-04 *
#   7.1634
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch27, lossVariable containing:
# 1.00000e-04 *
#   7.2982
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch28, lossVariable containing:
# 1.00000e-04 *
#   6.7783
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch29, lossVariable containing:
# 1.00000e-04 *
#   6.6033
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch30, lossVariable containing:
# 1.00000e-04 *
#   5.9723
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch31, lossVariable containing:
# 1.00000e-04 *
#   6.0733
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch32, lossVariable containing:
# 1.00000e-04 *
#   5.8039
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch33, lossVariable containing:
# 1.00000e-04 *
#   5.6909
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch34, lossVariable containing:
# 1.00000e-04 *
#   5.3457
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch35, lossVariable containing:
# 1.00000e-04 *
#   5.3304
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch36, lossVariable containing:
# 1.00000e-04 *
#   4.9437
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch37, lossVariable containing:
# 1.00000e-04 *
#   4.8818
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch38, lossVariable containing:
# 1.00000e-04 *
#   4.8073
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch39, lossVariable containing:
# 1.00000e-04 *
#   4.6508
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch40, lossVariable containing:
# 1.00000e-04 *
#   4.5677
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch41, lossVariable containing:
# 1.00000e-04 *
#   4.4645
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch42, lossVariable containing:
# 1.00000e-04 *
#   4.2580
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch43, lossVariable containing:
# 1.00000e-04 *
#   4.1705
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch44, lossVariable containing:
# 1.00000e-04 *
#   3.9883
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch45, lossVariable containing:
# 1.00000e-04 *
#   3.9448
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch46, lossVariable containing:
# 1.00000e-04 *
#   3.8870
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch47, lossVariable containing:
# 1.00000e-04 *
#   3.8008
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch48, lossVariable containing:
# 1.00000e-04 *
#   3.6714
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch49, lossVariable containing:
# 1.00000e-04 *
#   3.5696
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch50, lossVariable containing:
# 1.00000e-04 *
#   3.4162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch51, lossVariable containing:
# 1.00000e-04 *
#   3.5085
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch52, lossVariable containing:
# 1.00000e-04 *
#   3.4696
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch53, lossVariable containing:
# 1.00000e-04 *
#   3.2582
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch54, lossVariable containing:
# 1.00000e-04 *
#   3.2453
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch55, lossVariable containing:
# 1.00000e-04 *
#   3.0434
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch56, lossVariable containing:
# 1.00000e-04 *
#   3.1345
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch57, lossVariable containing:
# 1.00000e-04 *
#   3.0233
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch58, lossVariable containing:
# 1.00000e-04 *
#   3.0233
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch59, lossVariable containing:
# 1.00000e-04 *
#   2.8310
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch60, lossVariable containing:
# 1.00000e-04 *
#   2.8893
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch61, lossVariable containing:
# 1.00000e-04 *
#   2.8250
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch62, lossVariable containing:
# 1.00000e-04 *
#   2.6413
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch63, lossVariable containing:
# 1.00000e-04 *
#   2.8082
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch64, lossVariable containing:
# 1.00000e-04 *
#   2.6197
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch65, lossVariable containing:
# 1.00000e-04 *
#   2.5988
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch66, lossVariable containing:
# 1.00000e-04 *
#   2.5614
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch67, lossVariable containing:
# 1.00000e-04 *
#   2.5958
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch68, lossVariable containing:
# 1.00000e-04 *
#   2.4437
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch69, lossVariable containing:
# 1.00000e-04 *
#   2.5094
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch70, lossVariable containing:
# 1.00000e-04 *
#   2.3980
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch71, lossVariable containing:
# 1.00000e-04 *
#   2.7411
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch72, lossVariable containing:
# 1.00000e-04 *
#   2.4196
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch73, lossVariable containing:
# 1.00000e-04 *
#   2.4166
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch74, lossVariable containing:
# 1.00000e-04 *
#   2.2045
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch75, lossVariable containing:
# 1.00000e-04 *
#   2.2814
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch76, lossVariable containing:
# 1.00000e-04 *
#   2.2868
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch77, lossVariable containing:
# 1.00000e-04 *
#   2.2115
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch78, lossVariable containing:
# 1.00000e-04 *
#   2.0756
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch79, lossVariable containing:
# 1.00000e-04 *
#   2.1355
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch80, lossVariable containing:
# 1.00000e-04 *
#   2.1188
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch81, lossVariable containing:
# 1.00000e-04 *
#   2.1023
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch82, lossVariable containing:
# 1.00000e-04 *
#   2.0364
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# epoch83, lossVariable containing:
# 1.00000e-04 *
#   1.9236
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch84, lossVariable containing:
# 1.00000e-04 *
#   1.9162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch85, lossVariable containing:
# 1.00000e-04 *
#   1.9710
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch86, lossVariable containing:
# 1.00000e-04 *
#   1.9420
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch87, lossVariable containing:
# 1.00000e-04 *
#   1.8586
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch88, lossVariable containing:
# 1.00000e-04 *
#   1.8672
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch89, lossVariable containing:
# 1.00000e-04 *
#   1.8335
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch90, lossVariable containing:
# 1.00000e-04 *
#   1.7722
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch91, lossVariable containing:
# 1.00000e-04 *
#   1.7807
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch92, lossVariable containing:
# 1.00000e-04 *
#   1.7081
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch93, lossVariable containing:
# 1.00000e-04 *
#   1.8397
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch94, lossVariable containing:
# 1.00000e-04 *
#   1.7298
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch95, lossVariable containing:
# 1.00000e-04 *
#   1.7243
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch96, lossVariable containing:
# 1.00000e-04 *
#   1.7432
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch97, lossVariable containing:
# 1.00000e-04 *
#   1.6404
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch98, lossVariable containing:
# 1.00000e-04 *
#   1.7115
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch99, lossVariable containing:
# 1.00000e-04 *
#   1.6447
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Finished Training

# %%
# learning_rate = 5e-5
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, amsgrad=True)
# LOSS, Test_LOSS= cifartrain()
# sio.savemat('amsgrad_res1.mat',{'loss':LOSS})
# Out:
# epoch0, lossVariable containing:
#  1.3858
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch1, lossVariable containing:
#  0.9398
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch2, lossVariable containing:
#  0.6760
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch3, lossVariable containing:
#  0.4355
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch4, lossVariable containing:
#  0.2204
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch5, lossVariable containing:
#  0.1019
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch6, lossVariable containing:
# 1.00000e-02 *
#   4.4211
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch7, lossVariable containing:
# 1.00000e-02 *
#   1.9033
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch8, lossVariable containing:
# 1.00000e-03 *
#   8.5368
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch9, lossVariable containing:
# 1.00000e-03 *
#   5.4792
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch10, lossVariable containing:
# 1.00000e-03 *
#   4.0852
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch11, lossVariable containing:
# 1.00000e-03 *
#   3.3770
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch12, lossVariable containing:
# 1.00000e-03 *
#   2.8438
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch13, lossVariable containing:
# 1.00000e-03 *
#   2.3695
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch14, lossVariable containing:
# 1.00000e-03 *
#   2.3628
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch15, lossVariable containing:
# 1.00000e-03 *
#   1.9871
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch16, lossVariable containing:
# 1.00000e-03 *
#   1.8822
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch17, lossVariable containing:
# 1.00000e-03 *
#   1.7012
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch18, lossVariable containing:
# 1.00000e-03 *
#   1.5243
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch19, lossVariable containing:
# 1.00000e-03 *
#   1.4149
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch20, lossVariable containing:
# 1.00000e-03 *
#   1.3802
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch21, lossVariable containing:
# 1.00000e-03 *
#   1.3073
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch22, lossVariable containing:
# 1.00000e-03 *
#   1.1948
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch23, lossVariable containing:
# 1.00000e-03 *
#   1.0878
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch24, lossVariable containing:
# 1.00000e-03 *
#   1.0364
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch25, lossVariable containing:
# 1.00000e-03 *
#   1.0098
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch26, lossVariable containing:
# 1.00000e-04 *
#   9.4365
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch27, lossVariable containing:
# 1.00000e-04 *
#   9.1483
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch28, lossVariable containing:
# 1.00000e-04 *
#   8.7459
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch29, lossVariable containing:
# 1.00000e-04 *
#   8.4521
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch30, lossVariable containing:
# 1.00000e-04 *
#   7.9722
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch31, lossVariable containing:
# 1.00000e-04 *
#   7.9031
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch32, lossVariable containing:
# 1.00000e-04 *
#   7.5163
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch33, lossVariable containing:
# 1.00000e-04 *
#   7.0275
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch34, lossVariable containing:
# 1.00000e-04 *
#   6.9560
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch35, lossVariable containing:
# 1.00000e-04 *
#   6.6237
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch36, lossVariable containing:
# 1.00000e-04 *
#   6.4418
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch37, lossVariable containing:
# 1.00000e-04 *
#   6.4118
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch38, lossVariable containing:
# 1.00000e-04 *
#   5.9654
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch39, lossVariable containing:
# 1.00000e-04 *
#   6.0486
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch40, lossVariable containing:
# 1.00000e-04 *
#   5.5355
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch41, lossVariable containing:
# 1.00000e-04 *
#   5.5556
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch42, lossVariable containing:
# 1.00000e-04 *
#   5.4141
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch43, lossVariable containing:
# 1.00000e-04 *
#   5.6413
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch44, lossVariable containing:
# 1.00000e-04 *
#   5.2312
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch45, lossVariable containing:
# 1.00000e-04 *
#   5.0049
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch46, lossVariable containing:
# 1.00000e-04 *
#   4.9162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch47, lossVariable containing:
# 1.00000e-04 *
#   4.7552
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch48, lossVariable containing:
# 1.00000e-04 *
#   4.7451
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch49, lossVariable containing:
# 1.00000e-04 *
#   4.6222
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch50, lossVariable containing:
# 1.00000e-04 *
#   4.4871
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch51, lossVariable containing:
# 1.00000e-04 *
#   4.2774
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch52, lossVariable containing:
# 1.00000e-04 *
#   4.5280
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch53, lossVariable containing:
# 1.00000e-04 *
#   4.1708
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch54, lossVariable containing:
# 1.00000e-04 *
#   4.1786
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch55, lossVariable containing:
# 1.00000e-04 *
#   4.0732
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch56, lossVariable containing:
# 1.00000e-04 *
#   4.0083
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch57, lossVariable containing:
# 1.00000e-04 *
#   3.9233
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch58, lossVariable containing:
# 1.00000e-04 *
#   4.0246
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch59, lossVariable containing:
# 1.00000e-04 *
#   3.7386
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch60, lossVariable containing:
# 1.00000e-04 *
#   3.6679
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch61, lossVariable containing:
# 1.00000e-04 *
#   3.5153
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch62, lossVariable containing:
# 1.00000e-04 *
#   3.5983
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch63, lossVariable containing:
# 1.00000e-04 *
#   3.3805
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch64, lossVariable containing:
# 1.00000e-04 *
#   3.4099
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch65, lossVariable containing:
# 1.00000e-04 *
#   3.4370
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch66, lossVariable containing:
# 1.00000e-04 *
#   3.5199
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch67, lossVariable containing:
# 1.00000e-04 *
#   3.3096
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch68, lossVariable containing:
# 1.00000e-04 *
#   3.2481
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch69, lossVariable containing:
# 1.00000e-04 *
#   3.2472
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch70, lossVariable containing:
# 1.00000e-04 *
#   3.0629
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch71, lossVariable containing:
# 1.00000e-04 *
#   3.0285
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch72, lossVariable containing:
# 1.00000e-04 *
#   3.1443
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch73, lossVariable containing:
# 1.00000e-04 *
#   3.0867
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch74, lossVariable containing:
# 1.00000e-04 *
#   2.9439
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch75, lossVariable containing:
# 1.00000e-04 *
#   2.8522
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch76, lossVariable containing:
# 1.00000e-04 *
#   2.9885
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch77, lossVariable containing:
# 1.00000e-04 *
#   2.7546
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch78, lossVariable containing:
# 1.00000e-04 *
#   2.8606
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch79, lossVariable containing:
# 1.00000e-04 *
#   2.6791
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch80, lossVariable containing:
# 1.00000e-04 *
#   2.9413
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch81, lossVariable containing:
# 1.00000e-04 *
#   2.6478
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch82, lossVariable containing:
# 1.00000e-04 *
#   2.5898
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# epoch83, lossVariable containing:
# 1.00000e-04 *
#   2.5994
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch84, lossVariable containing:
# 1.00000e-04 *
#   2.5262
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch85, lossVariable containing:
# 1.00000e-04 *
#   2.5318
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch86, lossVariable containing:
# 1.00000e-04 *
#   2.3552
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch87, lossVariable containing:
# 1.00000e-04 *
#   2.6358
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch88, lossVariable containing:
# 1.00000e-04 *
#   2.4442
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch89, lossVariable containing:
# 1.00000e-04 *
#   2.3429
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch90, lossVariable containing:
# 1.00000e-04 *
#   2.3568
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch91, lossVariable containing:
# 1.00000e-04 *
#   2.3070
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch92, lossVariable containing:
# 1.00000e-04 *
#   2.3768
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch93, lossVariable containing:
# 1.00000e-04 *
#   2.2777
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch94, lossVariable containing:
# 1.00000e-04 *
#   2.2668
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch95, lossVariable containing:
# 1.00000e-04 *
#   2.2325
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch96, lossVariable containing:
# 1.00000e-04 *
#   2.2067
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch97, lossVariable containing:
# 1.00000e-04 *
#   2.2879
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch98, lossVariable containing:
# 1.00000e-04 *
#   2.1294
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch99, lossVariable containing:
# 1.00000e-04 *
#   2.9111
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Finished Training

# %%
# learning_rate = 6e-5
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# optimizer = Adam(net.parameters(), lr=learning_rate, betas=(0.9, 0.99), amsgrad=True)
# LOSS, Test_LOSS= cifartrain()
# sio.savemat('amsgrad_res2.mat',{'loss':LOSS})
# Out:
# epoch0, lossVariable containing:
#  1.3698
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch1, lossVariable containing:
#  0.9132
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch2, lossVariable containing:
#  0.6540
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch3, lossVariable containing:
#  0.4146
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch4, lossVariable containing:
#  0.2094
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch5, lossVariable containing:
# 1.00000e-02 *
#   9.4387
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch6, lossVariable containing:
# 1.00000e-02 *
#   3.9940
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch7, lossVariable containing:
# 1.00000e-02 *
#   1.7212
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch8, lossVariable containing:
# 1.00000e-03 *
#   9.6116
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch9, lossVariable containing:
# 1.00000e-03 *
#   6.2651
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch10, lossVariable containing:
# 1.00000e-03 *
#   4.9588
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch11, lossVariable containing:
# 1.00000e-03 *
#   3.9406
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch12, lossVariable containing:
# 1.00000e-03 *
#   3.4085
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch13, lossVariable containing:
# 1.00000e-03 *
#   2.9733
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch14, lossVariable containing:
# 1.00000e-03 *
#   2.6054
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch15, lossVariable containing:
# 1.00000e-03 *
#   2.3661
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch16, lossVariable containing:
# 1.00000e-03 *
#   2.2703
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch17, lossVariable containing:
# 1.00000e-03 *
#   2.0186
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch18, lossVariable containing:
# 1.00000e-03 *
#   1.9244
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch19, lossVariable containing:
# 1.00000e-03 *
#   1.7683
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch20, lossVariable containing:
# 1.00000e-03 *
#   1.6369
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch21, lossVariable containing:
# 1.00000e-03 *
#   1.5721
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch22, lossVariable containing:
# 1.00000e-03 *
#   1.4546
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch23, lossVariable containing:
# 1.00000e-03 *
#   1.4016
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch24, lossVariable containing:
# 1.00000e-03 *
#   1.3080
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch25, lossVariable containing:
# 1.00000e-03 *
#   1.2524
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch26, lossVariable containing:
# 1.00000e-03 *
#   1.2501
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch27, lossVariable containing:
# 1.00000e-03 *
#   1.2122
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch28, lossVariable containing:
# 1.00000e-03 *
#   1.1081
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch29, lossVariable containing:
# 1.00000e-03 *
#   1.0795
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch30, lossVariable containing:
# 1.00000e-04 *
#   9.8492
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch31, lossVariable containing:
# 1.00000e-04 *
#   9.5411
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch32, lossVariable containing:
# 1.00000e-04 *
#   8.9924
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch33, lossVariable containing:
# 1.00000e-04 *
#   8.9196
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch34, lossVariable containing:
# 1.00000e-04 *
#   8.5344
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch35, lossVariable containing:
# 1.00000e-04 *
#   8.3196
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch36, lossVariable containing:
# 1.00000e-04 *
#   8.1387
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch37, lossVariable containing:
# 1.00000e-04 *
#   7.8778
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch38, lossVariable containing:
# 1.00000e-04 *
#   7.7763
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch39, lossVariable containing:
# 1.00000e-04 *
#   7.2708
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch40, lossVariable containing:
# 1.00000e-04 *
#   7.3616
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch41, lossVariable containing:
# 1.00000e-04 *
#   7.4991
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch42, lossVariable containing:
# 1.00000e-04 *
#   6.8607
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch43, lossVariable containing:
# 1.00000e-04 *
#   6.3633
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch44, lossVariable containing:
# 1.00000e-04 *
#   6.3322
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch45, lossVariable containing:
# 1.00000e-04 *
#   5.9829
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch46, lossVariable containing:
# 1.00000e-04 *
#   6.1903
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch47, lossVariable containing:
# 1.00000e-04 *
#   5.8908
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch48, lossVariable containing:
# 1.00000e-04 *
#   5.6209
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch49, lossVariable containing:
# 1.00000e-04 *
#   5.4604
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch50, lossVariable containing:
# 1.00000e-04 *
#   5.4837
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch51, lossVariable containing:
# 1.00000e-04 *
#   5.2570
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch52, lossVariable containing:
# 1.00000e-04 *
#   5.3613
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch53, lossVariable containing:
# 1.00000e-04 *
#   5.1598
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch54, lossVariable containing:
# 1.00000e-04 *
#   5.1466
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch55, lossVariable containing:
# 1.00000e-04 *
#   4.9776
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch56, lossVariable containing:
# 1.00000e-04 *
#   4.8431
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch57, lossVariable containing:
# 1.00000e-04 *
#   4.6612
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch58, lossVariable containing:
# 1.00000e-04 *
#   4.6910
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch59, lossVariable containing:
# 1.00000e-04 *
#   4.8329
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch60, lossVariable containing:
# 1.00000e-04 *
#   4.6325
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch61, lossVariable containing:
# 1.00000e-04 *
#   4.4863
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch62, lossVariable containing:
# 1.00000e-04 *
#   4.4403
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch63, lossVariable containing:
# 1.00000e-04 *
#   4.3168
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch64, lossVariable containing:
# 1.00000e-04 *
#   4.1772
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch65, lossVariable containing:
# 1.00000e-04 *
#   4.1959
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch66, lossVariable containing:
# 1.00000e-04 *
#   4.0527
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch67, lossVariable containing:
# 1.00000e-04 *
#   3.8973
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch68, lossVariable containing:
# 1.00000e-04 *
#   4.1081
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch69, lossVariable containing:
# 1.00000e-04 *
#   3.7662
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch70, lossVariable containing:
# 1.00000e-04 *
#   3.7999
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch71, lossVariable containing:
# 1.00000e-04 *
#   3.5865
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch72, lossVariable containing:
# 1.00000e-04 *
#   3.7661
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch73, lossVariable containing:
# 1.00000e-04 *
#   3.5404
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch74, lossVariable containing:
# 1.00000e-04 *
#   3.4548
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch75, lossVariable containing:
# 1.00000e-04 *
#   3.7046
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch76, lossVariable containing:
# 1.00000e-04 *
#   3.3973
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch77, lossVariable containing:
# 1.00000e-04 *
#   3.4386
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch78, lossVariable containing:
# 1.00000e-04 *
#   3.3354
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch79, lossVariable containing:
# 1.00000e-04 *
#   3.2763
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch80, lossVariable containing:
# 1.00000e-04 *
#   3.3512
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch81, lossVariable containing:
# 1.00000e-04 *
#   3.2565
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# epoch82, lossVariable containing:
# 1.00000e-04 *
#   3.2641
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch83, lossVariable containing:
# 1.00000e-04 *
#   3.2866
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch84, lossVariable containing:
# 1.00000e-04 *
#   3.0632
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch85, lossVariable containing:
# 1.00000e-04 *
#   3.0229
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch86, lossVariable containing:
# 1.00000e-04 *
#   3.0981
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch87, lossVariable containing:
# 1.00000e-04 *
#   3.1734
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch88, lossVariable containing:
# 1.00000e-04 *
#   3.0203
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch89, lossVariable containing:
# 1.00000e-04 *
#   2.8576
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch90, lossVariable containing:
# 1.00000e-04 *
#   3.0485
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch91, lossVariable containing:
# 1.00000e-04 *
#   2.8847
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch92, lossVariable containing:
# 1.00000e-04 *
#   2.9147
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch93, lossVariable containing:
# 1.00000e-04 *
#   2.8350
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch94, lossVariable containing:
# 1.00000e-04 *
#   2.7008
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch95, lossVariable containing:
# 1.00000e-04 *
#   2.7942
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch96, lossVariable containing:
# 1.00000e-04 *
#   2.6514
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch97, lossVariable containing:
# 1.00000e-04 *
#   2.7117
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch98, lossVariable containing:
# 1.00000e-04 *
#   2.6165
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch99, lossVariable containing:
# 1.00000e-04 *
#   2.5843
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Finished Training

# %%
learning_rate = 5.5e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
optimizer = AdaStab(net.parameters(), lr=learning_rate, gamma=0.05)
LOSS, Test_LOSS= cifartrain()
sio.savemat('nosadam_res2.mat',{'loss':LOSS})
# Out:
# epoch0, lossVariable containing:
#  1.3817
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch1, lossVariable containing:
#  0.9280
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch2, lossVariable containing:
#  0.6726
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch3, lossVariable containing:
#  0.4438
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch4, lossVariable containing:
#  0.2349
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch5, lossVariable containing:
#  0.1129
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch6, lossVariable containing:
# 1.00000e-02 *
#   5.3407
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch7, lossVariable containing:
# 1.00000e-02 *
#   2.7391
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch8, lossVariable containing:
# 1.00000e-02 *
#   1.4453
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch9, lossVariable containing:
# 1.00000e-03 *
#   6.5580
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch10, lossVariable containing:
# 1.00000e-03 *
#   3.6362
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch11, lossVariable containing:
# 1.00000e-03 *
#   2.7142
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch12, lossVariable containing:
# 1.00000e-03 *
#   2.1285
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch13, lossVariable containing:
# 1.00000e-03 *
#   1.8692
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch14, lossVariable containing:
# 1.00000e-03 *
#   1.5531
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch15, lossVariable containing:
# 1.00000e-03 *
#   1.5058
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch16, lossVariable containing:
# 1.00000e-03 *
#   1.2359
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch17, lossVariable containing:
# 1.00000e-03 *
#   1.0640
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch18, lossVariable containing:
# 1.00000e-04 *
#   9.9840
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch19, lossVariable containing:
# 1.00000e-04 *
#   9.1323
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch20, lossVariable containing:
# 1.00000e-04 *
#   8.4448
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch21, lossVariable containing:
# 1.00000e-04 *
#   7.6281
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch22, lossVariable containing:
# 1.00000e-04 *
#   6.8150
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch23, lossVariable containing:
# 1.00000e-04 *
#   6.5111
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch24, lossVariable containing:
# 1.00000e-04 *
#   6.1997
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch25, lossVariable containing:
# 1.00000e-04 *
#   5.7574
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch26, lossVariable containing:
# 1.00000e-04 *
#   5.2776
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch27, lossVariable containing:
# 1.00000e-04 *
#   5.2040
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch28, lossVariable containing:
# 1.00000e-04 *
#   4.7075
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch29, lossVariable containing:
# 1.00000e-04 *
#   4.4887
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch30, lossVariable containing:
# 1.00000e-04 *
#   4.1523
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch31, lossVariable containing:
# 1.00000e-04 *
#   4.1398
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch32, lossVariable containing:
# 1.00000e-04 *
#   3.9179
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch33, lossVariable containing:
# 1.00000e-04 *
#   3.8775
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch34, lossVariable containing:
# 1.00000e-04 *
#   3.5390
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch35, lossVariable containing:
# 1.00000e-04 *
#   3.3356
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch36, lossVariable containing:
# 1.00000e-04 *
#   3.2048
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch37, lossVariable containing:
# 1.00000e-04 *
#   3.1098
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch38, lossVariable containing:
# 1.00000e-04 *
#   2.9998
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch39, lossVariable containing:
# 1.00000e-04 *
#   2.9211
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch40, lossVariable containing:
# 1.00000e-04 *
#   2.6551
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch41, lossVariable containing:
# 1.00000e-04 *
#   2.6186
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch42, lossVariable containing:
# 1.00000e-04 *
#   2.5924
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch43, lossVariable containing:
# 1.00000e-04 *
#   2.4743
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch44, lossVariable containing:
# 1.00000e-04 *
#   2.4316
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch45, lossVariable containing:
# 1.00000e-04 *
#   2.4266
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch46, lossVariable containing:
# 1.00000e-04 *
#   2.3299
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch47, lossVariable containing:
# 1.00000e-04 *
#   2.1134
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch48, lossVariable containing:
# 1.00000e-04 *
#   2.0800
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch49, lossVariable containing:
# 1.00000e-04 *
#   2.1610
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch50, lossVariable containing:
# 1.00000e-04 *
#   2.0395
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch51, lossVariable containing:
# 1.00000e-04 *
#   1.9311
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch52, lossVariable containing:
# 1.00000e-04 *
#   1.9334
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch53, lossVariable containing:
# 1.00000e-04 *
#   1.8229
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch54, lossVariable containing:
# 1.00000e-04 *
#   1.8354
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch55, lossVariable containing:
# 1.00000e-04 *
#   1.6968
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch56, lossVariable containing:
# 1.00000e-04 *
#   1.7257
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch57, lossVariable containing:
# 1.00000e-04 *
#   1.6973
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch58, lossVariable containing:
# 1.00000e-04 *
#   1.6057
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch59, lossVariable containing:
# 1.00000e-04 *
#   1.5939
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch60, lossVariable containing:
# 1.00000e-04 *
#   1.4689
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch61, lossVariable containing:
# 1.00000e-04 *
#   1.5360
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch62, lossVariable containing:
# 1.00000e-04 *
#   1.4660
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch63, lossVariable containing:
# 1.00000e-04 *
#   1.4145
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch64, lossVariable containing:
# 1.00000e-04 *
#   1.3900
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch65, lossVariable containing:
# 1.00000e-04 *
#   1.2693
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch66, lossVariable containing:
# 1.00000e-04 *
#   1.3057
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch67, lossVariable containing:
# 1.00000e-04 *
#   1.2406
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch68, lossVariable containing:
# 1.00000e-04 *
#   1.2126
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch69, lossVariable containing:
# 1.00000e-04 *
#   1.3107
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch70, lossVariable containing:
# 1.00000e-04 *
#   1.1795
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch71, lossVariable containing:
# 1.00000e-04 *
#   1.1396
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch72, lossVariable containing:
# 1.00000e-04 *
#   1.1012
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch73, lossVariable containing:
# 1.00000e-04 *
#   1.0773
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch74, lossVariable containing:
# 1.00000e-04 *
#   1.3646
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch75, lossVariable containing:
# 1.00000e-04 *
#   1.1567
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch76, lossVariable containing:
# 1.00000e-04 *
#   1.2261
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch77, lossVariable containing:
# 1.00000e-04 *
#   1.0745
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch78, lossVariable containing:
# 1.00000e-04 *
#   1.0393
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch79, lossVariable containing:
# 1.00000e-05 *
#   9.6898
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch80, lossVariable containing:
# 1.00000e-05 *
#   9.7074
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch81, lossVariable containing:
# 1.00000e-04 *
#   1.1910
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch82, lossVariable containing:
# 1.00000e-05 *
#   9.6874
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# epoch83, lossVariable containing:
# 1.00000e-05 *
#   9.2639
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch84, lossVariable containing:
# 1.00000e-05 *
#   9.1441
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch85, lossVariable containing:
# 1.00000e-05 *
#   9.6740
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch86, lossVariable containing:
# 1.00000e-05 *
#   8.6898
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch87, lossVariable containing:
# 1.00000e-05 *
#   8.3940
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch88, lossVariable containing:
# 1.00000e-05 *
#   8.4343
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch89, lossVariable containing:
# 1.00000e-05 *
#   8.0498
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch90, lossVariable containing:
# 1.00000e-05 *
#   8.0564
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch91, lossVariable containing:
# 1.00000e-05 *
#   8.1853
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch92, lossVariable containing:
# 1.00000e-05 *
#   7.5345
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch93, lossVariable containing:
# 1.00000e-05 *
#   7.5486
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch94, lossVariable containing:
# 1.00000e-05 *
#   7.4317
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch95, lossVariable containing:
# 1.00000e-05 *
#   7.3566
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch96, lossVariable containing:
# 1.00000e-05 *
#   7.2061
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch97, lossVariable containing:
# 1.00000e-05 *
#   7.0430
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch98, lossVariable containing:
# 1.00000e-05 *
#   7.2307
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch99, lossVariable containing:
# 1.00000e-05 *
#   6.7003
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Finished Training

# %%
# learning_rate = 4.5e-5
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# optimizer = AdaStab(net.parameters(), lr=learning_rate, gamma=0.05)
# LOSS, Test_LOSS= cifartrain()
# sio.savemat('nosadam_res3.mat',{'loss':LOSS})
# Out:
# epoch0, lossVariable containing:
#  1.4180
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch1, lossVariable containing:
#  0.9779
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch2, lossVariable containing:
#  0.7326
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch3, lossVariable containing:
#  0.4975
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch4, lossVariable containing:
#  0.2847
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch5, lossVariable containing:
#  0.1392
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch6, lossVariable containing:
# 1.00000e-02 *
#   6.2383
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch7, lossVariable containing:
# 1.00000e-02 *
#   3.1329
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch8, lossVariable containing:
# 1.00000e-02 *
#   1.4930
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch9, lossVariable containing:
# 1.00000e-02 *
#   1.0283
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch10, lossVariable containing:
# 1.00000e-03 *
#   5.3139
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch11, lossVariable containing:
# 1.00000e-03 *
#   3.9845
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch12, lossVariable containing:
# 1.00000e-03 *
#   3.1391
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch13, lossVariable containing:
# 1.00000e-03 *
#   2.5665
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-bea9e809372e> in <module>()
#       6 Test_LOSS = np.zeros([1, max_epoch])
#       7 optimizer = AdaStab(net.parameters(), lr=learning_rate, gamma=0.05)
# ----> 8 LOSS, Test_LOSS= cifartrain()
#       9 sio.savemat('nosadam_res3.mat',{'loss':LOSS})
#
# <ipython-input-6-5a237f3e6f55> in cifartrain()
#       8             inputs = Variable(inputs)
#       9             labels = Variable(labels)
# ---> 10             inputs = inputs.cuda()
#      11             labels = labels.cuda()
#      12
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/autograd/variable.py in cuda(self, device, async)
#     296
#     297     def cuda(self, device=None, async=False):
# --> 298         return CudaTransfer.apply(self, device, async)
#     299
#     300     def cpu(self):
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, device, async)
#     199             return i.cuda(device, async=async)
#     200         else:
# --> 201             return i.cuda(async=async)
#     202
#     203     @staticmethod
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/_utils.py in _cuda(self, device, async)
#      67         else:
#      68             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 69             return new_type(self.size()).copy_(self, async)
#      70
#      71
#
# KeyboardInterrupt:

# %% [markdown]
# # Adam

# %%
max_epoch=10

# %%
learning_rate = 6e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, amsgrad=False)
LOSS, Test_LOSS= cifartrain()
# sio.savemat('adam_res.mat',{'loss':LOSS})
# Out:
# epoch0, lossVariable containing:
#  1.3776
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch1, lossVariable containing:
#  0.9123
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch2, lossVariable containing:
#  0.6554
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch3, lossVariable containing:
#  0.4343
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch4, lossVariable containing:
#  0.2325
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch5, lossVariable containing:
#  0.1172
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch6, lossVariable containing:
# 1.00000e-02 *
#   6.4895
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch7, lossVariable containing:
# 1.00000e-02 *
#   4.8780
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch8, lossVariable containing:
# 1.00000e-02 *
#   6.5994
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch9, lossVariable containing:
# 1.00000e-02 *
#   7.0446
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Finished Training

# %%
learning_rate = 5e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, amsgrad=False)
LOSS, Test_LOSS= cifartrain()
# sio.savemat('adam_res.mat',{'loss':LOSS})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-626a1552b1f9> in <module>()
#       6 Test_LOSS = np.zeros([1, max_epoch])
#       7 optimizer = Adam(net.parameters(), lr=learning_rate, amsgrad=False)
# ----> 8 LOSS, Test_LOSS= cifartrain()
#       9 # sio.savemat('adam_res.mat',{'loss':LOSS})
#
# <ipython-input-6-5a237f3e6f55> in cifartrain()
#       8             inputs = Variable(inputs)
#       9             labels = Variable(labels)
# ---> 10             inputs = inputs.cuda()
#      11             labels = labels.cuda()
#      12
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/autograd/variable.py in cuda(self, device, async)
#     296
#     297     def cuda(self, device=None, async=False):
# --> 298         return CudaTransfer.apply(self, device, async)
#     299
#     300     def cpu(self):
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, device, async)
#     199             return i.cuda(device, async=async)
#     200         else:
# --> 201             return i.cuda(async=async)
#     202
#     203     @staticmethod
#
# /opt/software/anaconda/3/lib/python3.6/site-packages/torch/_utils.py in _cuda(self, device, async)
#      67         else:
#      68             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 69             return new_type(self.size()).copy_(self, async)
#      70
#      71
#
# KeyboardInterrupt:

# %%
learning_rate = 4e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, amsgrad=False)
LOSS, Test_LOSS= cifartrain()
# sio.savemat('adam_res.mat',{'loss':LOSS})
# Out:
# epoch0, lossVariable containing:
#  1.4502
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch1, lossVariable containing:
#  1.0165
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch2, lossVariable containing:
#  0.7631
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch3, lossVariable containing:
#  0.5216
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch4, lossVariable containing:
#  0.2969
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch5, lossVariable containing:
#  0.1413
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch6, lossVariable containing:
# 1.00000e-02 *
#   6.9286
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch7, lossVariable containing:
# 1.00000e-02 *
#   4.2577
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch8, lossVariable containing:
# 1.00000e-02 *
#   3.5951
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch9, lossVariable containing:
# 1.00000e-02 *
#   4.9119
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Finished Training

# %%
max_epoch=100

# %%
learning_rate = 4e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate, amsgrad=False)
LOSS, Test_LOSS= cifartrain()
sio.savemat('adam_res1.mat',{'loss':LOSS})
# Out:
# epoch0, lossVariable containing:
#  1.4323
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch1, lossVariable containing:
#  0.9892
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch2, lossVariable containing:
#  0.7245
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch3, lossVariable containing:
#  0.4780
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch4, lossVariable containing:
#  0.2504
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch5, lossVariable containing:
#  0.1129
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch6, lossVariable containing:
# 1.00000e-02 *
#   5.0909
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch7, lossVariable containing:
# 1.00000e-02 *
#   3.0962
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch8, lossVariable containing:
# 1.00000e-02 *
#   4.1710
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch9, lossVariable containing:
# 1.00000e-02 *
#   7.2261
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch10, lossVariable containing:
# 1.00000e-02 *
#   4.8190
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch11, lossVariable containing:
# 1.00000e-02 *
#   3.5972
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch12, lossVariable containing:
# 1.00000e-02 *
#   3.2836
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch13, lossVariable containing:
# 1.00000e-02 *
#   3.9511
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch14, lossVariable containing:
# 1.00000e-02 *
#   4.0482
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch15, lossVariable containing:
# 1.00000e-02 *
#   3.3002
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch16, lossVariable containing:
# 1.00000e-02 *
#   2.9473
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch17, lossVariable containing:
# 1.00000e-02 *
#   2.9855
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch18, lossVariable containing:
# 1.00000e-02 *
#   2.9168
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch19, lossVariable containing:
# 1.00000e-02 *
#   3.4071
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch20, lossVariable containing:
# 1.00000e-02 *
#   2.5162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch21, lossVariable containing:
# 1.00000e-02 *
#   2.8403
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch22, lossVariable containing:
# 1.00000e-02 *
#   2.6384
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch23, lossVariable containing:
# 1.00000e-02 *
#   2.7849
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch24, lossVariable containing:
# 1.00000e-02 *
#   2.2503
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch25, lossVariable containing:
# 1.00000e-02 *
#   1.7067
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch26, lossVariable containing:
# 1.00000e-02 *
#   2.8083
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch27, lossVariable containing:
# 1.00000e-02 *
#   3.1800
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch28, lossVariable containing:
# 1.00000e-02 *
#   1.7869
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch29, lossVariable containing:
# 1.00000e-02 *
#   1.7957
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch30, lossVariable containing:
# 1.00000e-02 *
#   1.9455
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch31, lossVariable containing:
# 1.00000e-02 *
#   2.9065
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch32, lossVariable containing:
# 1.00000e-02 *
#   2.8881
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch33, lossVariable containing:
# 1.00000e-02 *
#   1.5735
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch34, lossVariable containing:
# 1.00000e-02 *
#   1.7353
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch35, lossVariable containing:
# 1.00000e-02 *
#   1.3905
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch36, lossVariable containing:
# 1.00000e-02 *
#   1.9229
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch37, lossVariable containing:
# 1.00000e-02 *
#   2.2164
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch38, lossVariable containing:
# 1.00000e-02 *
#   2.4264
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch39, lossVariable containing:
# 1.00000e-02 *
#   1.6301
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch40, lossVariable containing:
# 1.00000e-02 *
#   1.2198
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch41, lossVariable containing:
# 1.00000e-02 *
#   1.4860
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch42, lossVariable containing:
# 1.00000e-02 *
#   2.5293
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch43, lossVariable containing:
# 1.00000e-02 *
#   2.1089
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch44, lossVariable containing:
# 1.00000e-02 *
#   1.3856
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch45, lossVariable containing:
# 1.00000e-02 *
#   1.3156
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch46, lossVariable containing:
# 1.00000e-02 *
#   1.3082
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch47, lossVariable containing:
# 1.00000e-02 *
#   2.4503
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch48, lossVariable containing:
# 1.00000e-02 *
#   1.5943
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch49, lossVariable containing:
# 1.00000e-02 *
#   1.4347
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch50, lossVariable containing:
# 1.00000e-02 *
#   1.4857
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch51, lossVariable containing:
# 1.00000e-02 *
#   1.6309
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch52, lossVariable containing:
# 1.00000e-03 *
#   7.6293
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch53, lossVariable containing:
# 1.00000e-02 *
#   1.7765
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch54, lossVariable containing:
# 1.00000e-02 *
#   2.1479
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch55, lossVariable containing:
# 1.00000e-02 *
#   1.3297
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch56, lossVariable containing:
# 1.00000e-02 *
#   1.0467
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch57, lossVariable containing:
# 1.00000e-02 *
#   1.3286
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch58, lossVariable containing:
# 1.00000e-02 *
#   1.8722
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch59, lossVariable containing:
# 1.00000e-02 *
#   1.5290
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch60, lossVariable containing:
# 1.00000e-03 *
#   7.9824
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch61, lossVariable containing:
# 1.00000e-03 *
#   5.7535
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch62, lossVariable containing:
# 1.00000e-02 *
#   1.2262
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch63, lossVariable containing:
# 1.00000e-02 *
#   2.7371
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch64, lossVariable containing:
# 1.00000e-02 *
#   1.4320
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch65, lossVariable containing:
# 1.00000e-03 *
#   6.8964
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch66, lossVariable containing:
# 1.00000e-03 *
#   3.6624
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch67, lossVariable containing:
# 1.00000e-03 *
#   6.2753
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch68, lossVariable containing:
# 1.00000e-02 *
#   2.8443
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch69, lossVariable containing:
# 1.00000e-02 *
#   1.8996
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch70, lossVariable containing:
# 1.00000e-03 *
#   8.5675
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch71, lossVariable containing:
# 1.00000e-03 *
#   5.6490
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch72, lossVariable containing:
# 1.00000e-03 *
#   3.5963
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch73, lossVariable containing:
# 1.00000e-02 *
#   1.8119
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch74, lossVariable containing:
# 1.00000e-02 *
#   2.2493
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch75, lossVariable containing:
# 1.00000e-02 *
#   1.0983
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch76, lossVariable containing:
# 1.00000e-03 *
#   4.8567
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch77, lossVariable containing:
# 1.00000e-03 *
#   3.9931
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch78, lossVariable containing:
# 1.00000e-03 *
#   8.2660
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch79, lossVariable containing:
# 1.00000e-02 *
#   2.6049
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch80, lossVariable containing:
# 1.00000e-02 *
#   1.0937
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch81, lossVariable containing:
# 1.00000e-03 *
#   7.8673
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch82, lossVariable containing:
# 1.00000e-03 *
#   4.2431
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# epoch83, lossVariable containing:
# 1.00000e-03 *
#   5.8893
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch84, lossVariable containing:
# 1.00000e-02 *
#   1.6204
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch85, lossVariable containing:
# 1.00000e-02 *
#   1.7327
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch86, lossVariable containing:
# 1.00000e-02 *
#   1.2838
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch87, lossVariable containing:
# 1.00000e-03 *
#   5.0789
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch88, lossVariable containing:
# 1.00000e-03 *
#   2.4896
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch89, lossVariable containing:
# 1.00000e-03 *
#   6.8553
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch90, lossVariable containing:
# 1.00000e-02 *
#   2.2075
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch91, lossVariable containing:
# 1.00000e-02 *
#   1.1914
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch92, lossVariable containing:
# 1.00000e-03 *
#   7.8539
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch93, lossVariable containing:
# 1.00000e-03 *
#   5.5040
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch94, lossVariable containing:
# 1.00000e-03 *
#   5.1794
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch95, lossVariable containing:
# 1.00000e-02 *
#   1.5474
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch96, lossVariable containing:
# 1.00000e-02 *
#   1.0626
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch97, lossVariable containing:
# 1.00000e-03 *
#   5.6670
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch98, lossVariable containing:
# 1.00000e-02 *
#   1.1312
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch99, lossVariable containing:
# 1.00000e-02 *
#   1.2798
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Finished Training

# %%
learning_rate = 4e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
optimizer = Adam(net.parameters(), lr=learning_rate,betas=(0.9, 0.99), amsgrad=False)
LOSS, Test_LOSS= cifartrain()
sio.savemat('adam_res2.mat',{'loss':LOSS})
# Out:
# epoch0, lossVariable containing:
#  1.4254
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch1, lossVariable containing:
#  0.9677
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch2, lossVariable containing:
#  0.7123
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch3, lossVariable containing:
#  0.4668
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch4, lossVariable containing:
#  0.2510
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch5, lossVariable containing:
#  0.1298
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch6, lossVariable containing:
# 1.00000e-02 *
#   7.8508
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch7, lossVariable containing:
# 1.00000e-02 *
#   6.2696
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch8, lossVariable containing:
# 1.00000e-02 *
#   5.4074
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch9, lossVariable containing:
# 1.00000e-02 *
#   4.7083
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch10, lossVariable containing:
# 1.00000e-02 *
#   4.7992
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch11, lossVariable containing:
# 1.00000e-02 *
#   4.2811
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch12, lossVariable containing:
# 1.00000e-02 *
#   3.9810
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch13, lossVariable containing:
# 1.00000e-02 *
#   3.9123
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch14, lossVariable containing:
# 1.00000e-02 *
#   3.6028
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch15, lossVariable containing:
# 1.00000e-02 *
#   3.5788
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch16, lossVariable containing:
# 1.00000e-02 *
#   3.4085
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch17, lossVariable containing:
# 1.00000e-02 *
#   3.2886
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch18, lossVariable containing:
# 1.00000e-02 *
#   3.0036
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch19, lossVariable containing:
# 1.00000e-02 *
#   2.7721
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch20, lossVariable containing:
# 1.00000e-02 *
#   3.2331
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch21, lossVariable containing:
# 1.00000e-02 *
#   2.7810
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch22, lossVariable containing:
# 1.00000e-02 *
#   2.8281
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch23, lossVariable containing:
# 1.00000e-02 *
#   2.7436
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch24, lossVariable containing:
# 1.00000e-02 *
#   2.1595
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch25, lossVariable containing:
# 1.00000e-02 *
#   2.6748
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch26, lossVariable containing:
# 1.00000e-02 *
#   2.4145
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch27, lossVariable containing:
# 1.00000e-02 *
#   2.6299
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch28, lossVariable containing:
# 1.00000e-02 *
#   2.1703
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch29, lossVariable containing:
# 1.00000e-02 *
#   2.3598
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch30, lossVariable containing:
# 1.00000e-02 *
#   2.3108
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch31, lossVariable containing:
# 1.00000e-02 *
#   1.9632
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch32, lossVariable containing:
# 1.00000e-02 *
#   2.1615
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch33, lossVariable containing:
# 1.00000e-02 *
#   2.0263
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch34, lossVariable containing:
# 1.00000e-02 *
#   1.9935
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch35, lossVariable containing:
# 1.00000e-02 *
#   1.9606
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch36, lossVariable containing:
# 1.00000e-02 *
#   2.0662
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch37, lossVariable containing:
# 1.00000e-02 *
#   1.9207
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch38, lossVariable containing:
# 1.00000e-02 *
#   2.2299
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch39, lossVariable containing:
# 1.00000e-02 *
#   1.8528
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch40, lossVariable containing:
# 1.00000e-02 *
#   1.6937
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch41, lossVariable containing:
# 1.00000e-02 *
#   1.6969
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch42, lossVariable containing:
# 1.00000e-02 *
#   1.5523
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch43, lossVariable containing:
# 1.00000e-02 *
#   1.8911
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch44, lossVariable containing:
# 1.00000e-02 *
#   1.5036
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch45, lossVariable containing:
# 1.00000e-02 *
#   1.9203
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch46, lossVariable containing:
# 1.00000e-02 *
#   1.5361
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch47, lossVariable containing:
# 1.00000e-02 *
#   1.4897
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch48, lossVariable containing:
# 1.00000e-02 *
#   1.6691
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch49, lossVariable containing:
# 1.00000e-02 *
#   1.5511
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch50, lossVariable containing:
# 1.00000e-02 *
#   1.4413
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch51, lossVariable containing:
# 1.00000e-02 *
#   1.6052
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch52, lossVariable containing:
# 1.00000e-02 *
#   1.4991
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch53, lossVariable containing:
# 1.00000e-02 *
#   1.4233
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch54, lossVariable containing:
# 1.00000e-02 *
#   1.3161
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch55, lossVariable containing:
# 1.00000e-02 *
#   1.3681
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch56, lossVariable containing:
# 1.00000e-02 *
#   1.7120
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch57, lossVariable containing:
# 1.00000e-02 *
#   1.3404
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch58, lossVariable containing:
# 1.00000e-02 *
#   1.3852
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch59, lossVariable containing:
# 1.00000e-02 *
#   1.3606
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch60, lossVariable containing:
# 1.00000e-02 *
#   1.4095
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch61, lossVariable containing:
# 1.00000e-02 *
#   1.3071
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch62, lossVariable containing:
# 1.00000e-02 *
#   1.2275
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch63, lossVariable containing:
# 1.00000e-02 *
#   1.1531
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch64, lossVariable containing:
# 1.00000e-02 *
#   1.3036
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch65, lossVariable containing:
# 1.00000e-02 *
#   1.3403
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch66, lossVariable containing:
# 1.00000e-02 *
#   1.1436
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch67, lossVariable containing:
# 1.00000e-02 *
#   1.2740
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch68, lossVariable containing:
# 1.00000e-02 *
#   1.2764
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch69, lossVariable containing:
# 1.00000e-02 *
#   1.2297
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch70, lossVariable containing:
# 1.00000e-02 *
#   1.0647
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch71, lossVariable containing:
# 1.00000e-02 *
#   1.1479
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch72, lossVariable containing:
# 1.00000e-02 *
#   1.1211
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch73, lossVariable containing:
# 1.00000e-02 *
#   1.2209
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch74, lossVariable containing:
# 1.00000e-02 *
#   1.1418
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch75, lossVariable containing:
# 1.00000e-02 *
#   1.1245
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch76, lossVariable containing:
# 1.00000e-02 *
#   1.1431
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch77, lossVariable containing:
# 1.00000e-03 *
#   9.7095
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch78, lossVariable containing:
# 1.00000e-02 *
#   1.2409
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch79, lossVariable containing:
# 1.00000e-03 *
#   8.8901
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch80, lossVariable containing:
# 1.00000e-02 *
#   1.1303
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch81, lossVariable containing:
# 1.00000e-02 *
#   1.0729
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch82, lossVariable containing:
# 1.00000e-02 *
#   1.1320
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# epoch83, lossVariable containing:
# 1.00000e-02 *
#   1.0707
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch84, lossVariable containing:
# 1.00000e-03 *
#   9.9261
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch85, lossVariable containing:
# 1.00000e-03 *
#   8.5545
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch86, lossVariable containing:
# 1.00000e-02 *
#   1.0604
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch87, lossVariable containing:
# 1.00000e-03 *
#   9.6010
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch88, lossVariable containing:
# 1.00000e-03 *
#   9.1138
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch89, lossVariable containing:
# 1.00000e-03 *
#   9.7684
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch90, lossVariable containing:
# 1.00000e-02 *
#   1.0246
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch91, lossVariable containing:
# 1.00000e-03 *
#   9.9778
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch92, lossVariable containing:
# 1.00000e-03 *
#   8.9885
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch93, lossVariable containing:
# 1.00000e-03 *
#   9.4136
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch94, lossVariable containing:
# 1.00000e-03 *
#   8.1799
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch95, lossVariable containing:
# 1.00000e-02 *
#   1.0387
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch96, lossVariable containing:
# 1.00000e-03 *
#   8.2044
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch97, lossVariable containing:
# 1.00000e-02 *
#   1.0251
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch98, lossVariable containing:
# 1.00000e-03 *
#   8.4976
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# epoch99, lossVariable containing:
# 1.00000e-02 *
#   1.0654
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Finished Training

# %% [markdown]
# ## AdaStab

# %%
# learning_rate = 1e-4
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# optimizer = AdaStab(net.parameters(), lr=learning_rate, gamma=0.05)
# LOSS, Test_LOSS= cifartrain()

# %%
# learning_rate = 2e-4
# net = ResNet18()
# net = net.cuda()
# criterion = nn.CrossEntropyLoss()
# LOSS = np.zeros([1, max_epoch])
# Test_LOSS = np.zeros([1, max_epoch])
# optimizer = AdaStab(net.parameters(), lr=learning_rate, gamma=0.05)
# LOSS, Test_LOSS= cifartrain()

# %%
learning_rate = 5e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
optimizer = AdaStab(net.parameters(), lr=learning_rate, gamma=0.05)
LOSS, Test_LOSS= cifartrain()

# %%
learning_rate = 6e-5
net = ResNet18()
net = net.cuda()
criterion = nn.CrossEntropyLoss()
LOSS = np.zeros([1, max_epoch])
Test_LOSS = np.zeros([1, max_epoch])
optimizer = AdaStab(net.parameters(), lr=learning_rate, gamma=0.05)
LOSS, Test_LOSS= cifartrain()
